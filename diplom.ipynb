# %% [markdown]
# ## Определение языка и перевод (+ обработка данных об изготовителе)
#
# На этом этапе:
# - Используем `langdetect` для определения языка;
# - Применяем `deep_translator` для перевода на английский;
# - Пропускаем перевод, если текст уже на английском;
# - Логируем необработанные случаи.

# %%
# !pip install deep-translator langdetect --quiet

import json
import sqlite3
import re
from deep_translator import GoogleTranslator
from langdetect import detect, DetectorFactory
from langdetect.lang_detect_exception import LangDetectException
import pandas as pd

# Стабильность результатов langdetect
DetectorFactory.seed = 42

# %%
def is_non_empty(text):
    return bool(text and text.strip())

def contains_cyrillic(text):
    return bool(re.search(r'[а-яА-Я]', text))

def detect_language(text):
    try:
        return detect(text)
    except LangDetectException:
        return "unknown"

def translate_to_english(text):
    if not text or text.strip() == "":
        return ""

    lang = detect_language(text)

    if lang == "en" and contains_cyrillic(text):
        force_translate = True
    else:
        force_translate = False

    if lang == "en" and not force_translate:
        return text
    elif lang == "unknown":
        print ("unkown", text)
        return text

    try:
        print(text,"\n")
        translated = GoogleTranslator(source='auto', target='en').translate(text)
        print(translated,"\n")
        return translated
    except Exception as e:
        print(f"Translation failed: '{text[:50]}...' — {e}")
        return text

# %%
#попытка разделить данные об изготовителе по тегам
def process_info(info_text):
    info_parts = info_text.split('<br><br>')

    info_dict = {
        "страна происхождения": "",
        "изготовитель": "",
        "ОГРН": "",
        "юридический адрес": "",
        "продавец": "",
        "info": ""
    }

    if len(info_parts) > 0:
        # Разбираем первую часть, которая содержит "страна происхождения"
        country_info = info_parts[0].strip()
        if '<br>' in country_info:
            country_parts = country_info.split('<br>', 1)
            info_dict["страна происхождения"] = country_parts[1].strip()

    if len(info_parts) > 1:
        # Обрабатываем "изготовитель"
        manufacturer_info = info_parts[1].strip()
        if '<br>' in manufacturer_info:
            manufacturer_parts = manufacturer_info.split('<br>', 1)
            info_dict["изготовитель"] = manufacturer_parts[1].strip()

    if len(info_parts) > 2:
        # Обрабатываем "продавец"
        seller_info = info_parts[2].strip()
        if '<br>' in seller_info:
            seller_parts = seller_info.split('<br>', 1)
            if len(seller_parts) > 1:
                info_dict["продавец"] = seller_parts[1].strip()

    if len(info_parts) > 3:
        # Обрабатываем "ОГРН"
        ogrn_info = info_parts[3].strip()
        if '<br>' in ogrn_info:
            ogrn_parts = ogrn_info.split('<br>', 1)
            info_dict["ОГРН"] = ogrn_parts[1].strip()

    if len(info_parts) > 4:
        # Обрабатываем "юридический адрес"
        address_info = info_parts[4].strip()
        if '<br>' in address_info:
            address_parts = address_info.split('<br>', 1)
            info_dict["юридический адрес"] = address_parts[1].strip()

    # Остальная информация записывается в "info"
    if len(info_parts) > 5:
        info_dict["info"] = ' '.join(info_parts[5:]).strip()

    return info_dict

# %%
def process_composition(composition):
    if not is_non_empty(composition):
        return ""

    composition = translate_to_english(composition)
    composition = composition.lower()

    return composition


def process_products(json_data):
    processed_data = []

    for index, product in enumerate(json_data):
        #print(f"Обработка продукта {index + 1} из {len(json_data)}: {product.get('itemId', 'Неизвестный itemId')}")

        product_info = product.get('info информация', '')

        # Обработка composition
        composition = product.get('composition', '')
        composition = process_composition(composition)

        # Обработка информации
        info_processed = process_info(product_info)

        processed_data.append({
            "itemId": product.get('itemId', ''),
            "name": product.get('name', ''),
            "type": product.get('type', ''),
            "brand": product.get('brand', ''),
            "productType": product.get('productType', ''),
            "composition": composition,
            "description": product.get('description', ''),
            "страна происхождения": info_processed["страна происхождения"],
            "изготовитель": info_processed["изготовитель"],
            "продавец": info_processed["продавец"],
            "ОГРН": info_processed["ОГРН"],
            "юридический адрес": info_processed["юридический адрес"],
            "info": info_processed["info"]
        })

    return processed_data

def save_to_db(processed_data):
    conn = sqlite3.connect('full_products_database.db')
    c = conn.cursor()

    c.execute('''CREATE TABLE IF NOT EXISTS merged_table (
                    itemId TEXT,
                    name TEXT,
                    type TEXT,
                    brand TEXT,
                    productType TEXT,
                    composition TEXT,
                    description TEXT,
                    страна_происхождения TEXT,
                    изготовитель TEXT,
                    продавец TEXT,
                    ОГРН TEXT,
                    юридический_адрес TEXT,
                    info TEXT
                )''')

    for product in processed_data:
        c.execute('''INSERT INTO merged_table (
                        itemId, name, type, brand, productType, composition, description,
                        страна_происхождения, изготовитель, продавец, ОГРН, юридический_адрес, info
                    ) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''', (
                        product['itemId'],
                        product['name'],
                        product['type'],
                        product['brand'],
                        product['productType'],
                        product['composition'],
                        product['description'],
                        product['страна происхождения'],
                        product['изготовитель'],
                        product['продавец'],
                        product['ОГРН'],
                        product['юридический адрес'],
                        product['info']
                    ))

    conn.commit()
    conn.close()

# %%
with open('merged_data.json', 'r', encoding='utf-8') as file:
    json_data = json.load(file)

processed_data = process_products(json_data)
save_to_db(processed_data)

# %% [markdown]
# ## Очистка и стандартизация текста
#
# На этом этапе:
# - Приводим текст к чистому и структурированному виду;
# - Удаляем HTML-теги, лишние пробелы и пунктуацию;
# - Приводим текст к нижнему регистру;
# - Применяем токенизацию и лемматизацию для составов и описаний;
# - Сохраняем важные конструкции (например, отрицания).

# %% [markdown]
# Обработаем описания средств. Удалим стоп-слова, но оставим нужные,
# например, отрицания - у них есть смысловая нагрузка

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.8.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.15.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.11.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.4.26)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)

# %%
# !python -m spacy download ru_core_news_sm
# Out:
# Collecting ru-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.8.0/ru_core_news_sm-3.8.0-py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 27.6 MB/s eta 0:00:00
# Collecting pymorphy3>=1.0.0 (from ru-core-news-sm==3.8.0)
#   Downloading pymorphy3-2.0.3-py3-none-any.whl.metadata (1.9 kB)
# Collecting dawg2-python>=0.8.0 (from pymorphy3>=1.0.0->ru-core-news-sm==3.8.0)
#   Downloading dawg2_python-0.9.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting pymorphy3-dicts-ru (from pymorphy3>=1.0.0->ru-core-news-sm==3.8.0)
#   Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl.metadata (2.0 kB)
# Downloading pymorphy3-2.0.3-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 1.9 MB/s eta 0:00:00
# Downloading dawg2_python-0.9.0-py3-none-any.whl (9.3 kB)
# Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 56.8 MB/s eta 0:00:00
# Installing collected packages: pymorphy3-dicts-ru, dawg2-python, pymorphy3, ru-core-news-sm
# Successfully installed dawg2-python-0.9.0 pymorphy3-2.0.3 pymorphy3-dicts-ru-2.4.417150.4580142 ru-core-news-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import sqlite3
import re
import spacy

# %%
nlp = spacy.load('ru_core_news_sm')

# %%
important_stopwords = {'не', 'нет', 'без', 'против', 'для', 'в', 'на'}

def preprocess_text(text):
    text = re.sub(r'<.*?>', '', text)

    text = " ".join(text.split())

    text = text.lower()

    text = re.sub(r'[^\w\s]', '', text)

    return text

def tokenize_text_russian(text):
    if text:
      text = preprocess_text(text)
      doc = nlp(text)
      tokens = [
            token.lemma_ for token in doc
            if not token.is_stop or token.text in important_stopwords
            and not token.is_punct
        ]
      return ' '.join(tokens)
    return ""

# %%
def tokenize_and_update_database(db_path):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()

    cursor.execute("PRAGMA table_info(merged_table);")
    columns = [column[1] for column in cursor.fetchall()]

    if 'description_tokens' not in columns:
        cursor.execute('''
            ALTER TABLE merged_table
            ADD COLUMN description_tokens TEXT;
        ''')
        conn.commit()

    cursor.execute("SELECT itemId, description FROM merged_table")
    rows = cursor.fetchall()

    # Токенизируем каждое описание и записываем результат в новую колонку
    for row in rows:
        itemId, description = row
        description_tokens = tokenize_text_russian(description)

        # Обновляем запись в базе данных
        cursor.execute('''
            UPDATE merged_table
            SET description_tokens = ?
            WHERE itemId = ?
        ''', (description_tokens, itemId))

    conn.commit()
    conn.close()

# %%
db_path = '/content/full_products_database.db'

tokenize_and_update_database(db_path)

print("Токенизация и обновление базы данных завершены.")
# Out:
# Токенизация и обновление базы данных завершены.

# %% [markdown]
# Теперь обработаем составы:

# %%
# !pip install scispacy
# !pip install spacy
# Out:
# Requirement already satisfied: scispacy in /usr/local/lib/python3.11/dist-packages (0.5.5)
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from scispacy) (3.7.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from scispacy) (1.15.2)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scispacy) (2.32.3)
# Requirement already satisfied: conllu in /usr/local/lib/python3.11/dist-packages (from scispacy) (6.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from scispacy) (1.26.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from scispacy) (1.4.2)
# Requirement already satisfied: scikit-learn>=0.20.3 in /usr/local/lib/python3.11/dist-packages (from scispacy) (1.6.1)
# Requirement already satisfied: pysbd in /usr/local/lib/python3.11/dist-packages (from scispacy) (0.3.4)
# Requirement already satisfied: nmslib-metabrainz==2.1.3 in /usr/local/lib/python3.11/dist-packages (from scispacy) (2.1.3)
# Requirement already satisfied: pybind11>=2.2.3 in /usr/local/lib/python3.11/dist-packages (from nmslib-metabrainz==2.1.3->scispacy) (2.13.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from nmslib-metabrainz==2.1.3->scispacy) (5.9.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (2025.4.26)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20.3->scispacy) (3.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (0.15.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (4.67.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.11.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->scispacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->scispacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->scispacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->scispacy) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->scispacy) (0.4.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->scispacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->scispacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->scispacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->scispacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->scispacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->scispacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (2.19.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->scispacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (0.1.2)
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.15.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.11.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.4.26)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_sm-0.5.4.tar.gz
# Out:
# Collecting https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_sm-0.5.4.tar.gz
#   Downloading https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_sm-0.5.4.tar.gz (14.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 14.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: spacy<3.8.0,>=3.7.4 in /usr/local/lib/python3.11/dist-packages (from en_core_sci_sm==0.5.4) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (0.15.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (2.11.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (2025.4.26)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (2.19.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en_core_sci_sm==0.5.4) (0.1.2)
# Building wheels for collected packages: en_core_sci_sm
#   Building wheel for en_core_sci_sm (setup.py) ... done
#   Created wheel for en_core_sci_sm: filename=en_core_sci_sm-0.5.4-py3-none-any.whl size=14778488 sha256=7956cffe136b8d970b00f61c6d5bcd1ae746a56ed5b729a3412e82b9313efe11
#   Stored in directory: /root/.cache/pip/wheels/7f/29/44/dd461872b8547b8e8007f03418fb8061f5c05c71447982bcff
# Successfully built en_core_sci_sm
# Installing collected packages: en_core_sci_sm
# Successfully installed en_core_sci_sm-0.5.4

# %%
import spacy
import scispacy
import re

nlp = spacy.load("en_core_sci_sm")
# Out:
# /usr/local/lib/python3.11/dist-packages/spacy/language.py:2195: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]

# %%
import requests
import time
import json

# %%
with open('chemical_data.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

components_with_404 = set(data.get("components_with_404", [])) # Множество для отслеживания химических веществ с ошибкой 404
synonyms_cache = data.get("synonyms_cache", {}) # Словарь для хранения синонимов химических веществ

def get_pubchem_synonyms(chemical_name, retries=7, delay=4, timeout=10):
    # Проверяем, если вещество уже есть в списке с ошибкой 404 или в кэше
    if chemical_name in components_with_404:
        print(f"Компонент {chemical_name} уже был с 404, пропускаем.")
        return []

    if chemical_name in synonyms_cache:
        print(f"Синонимы для {chemical_name} найдены в кэше.")
        return synonyms_cache[chemical_name]

    url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/{chemical_name}/synonyms/JSON"

    for attempt in range(retries):
        try:
            response = requests.get(url, timeout=timeout)

            if response.status_code == 404:
                print(f"404 для компонента {chemical_name} по ссылке {url} - добавляю в список ошибок")
                components_with_404.add(chemical_name)
                synonyms_cache[chemical_name] = []  # Сохраняем пустой список для компонента с 404
                return []

            if response.status_code == 503:
                print(f"503 для компонента {chemical_name} по ссылке {url} - сервер временно недоступен, ожидаем...")
                time.sleep(delay)
                delay *= 2
                continue

            response.raise_for_status()
            data = response.json()
            print(data)

            # Проверяем, есть ли в данных синонимы
            if "InformationList" in data and "Information" in data["InformationList"]:
                synonyms_info = data["InformationList"]["Information"][0]
                if 'Synonym' in synonyms_info:
                    synonyms = synonyms_info['Synonym']
                    synonyms_cache[chemical_name] = synonyms  # Сохраняем синонимы в кэш
                    return synonyms
                else:
                    print(f"Синонимы для {chemical_name} не найдены.")
                    components_with_404.add(chemical_name)  # Добавляем в список для пропуска в будущем
                    synonyms_cache[chemical_name] = []  # Сохраняем пустой список для отсутствующих синонимов
                    return []  # Нет синонимов, возвращаем пустой список
            else:
                print(f"Информация о синонимах для {chemical_name} отсутствует.")
                components_with_404.add(chemical_name)  # Добавляем в список для пропуска в будущем
                synonyms_cache[chemical_name] = []  # Сохраняем пустой список для отсутствующей информации
                return []

        except requests.exceptions.RequestException as e:
            print(f"Ошибка при получении данных для {chemical_name}: {e}")
            if attempt < retries - 1:
                print(f"Retrying... ({attempt + 1}/{retries})")
                time.sleep(delay)
                delay *= 2
            else:
                print(f"Не удалось получить данные для {chemical_name} после {retries} попыток.")
                components_with_404.add(chemical_name)  # Добавляем в список для пропуска в будущем
                synonyms_cache[chemical_name] = []  # Сохраняем пустой список для неудачного запроса
                return []

def save_data():
    with open('synonyms_data.json', 'w', encoding='utf-8') as f:
        json.dump({
            "components_with_404": list(components_with_404),
            "synonyms_cache": synonyms_cache
        }, f, ensure_ascii=False, indent=2)

# %%
def normalize_to_preferred_synonym(chemical_name):
    synonyms = get_pubchem_synonyms(chemical_name)
    if synonyms:
        # Используем первый синоним как предпочтительный
        preferred_synonym = synonyms[0].lower()
        return preferred_synonym
    else:
        return chemical_name.lower()

# %%
def normalize_tokens(doc):
    normalized_tokens = []
    previous_token = None

    for token in doc:
        if token.pos_ != 'PUNCT' and token.text.strip() != '' and token.text.lower() != 'leaf' and token.text.lower() != 'vitamin': # для этих слов почему-то неправильные синонимы
            normalized_name = normalize_to_preferred_synonym(token.text)  # Синхронный вызов

            # Если новый нормализованный токен отличается от предыдущего, добавляем его
            if normalized_name != previous_token:
                normalized_tokens.append(normalized_name)

            previous_token = normalized_name
        else:
            normalized_tokens.append(token.text)

    return normalized_tokens

# %%
def join_tokens_into_phrases(tokens):
    phrases = []
    current_phrase = []

    for token in tokens:
        if token not in {',', '.', ';', '•', '･'}:
            current_phrase.append(token)
        else:
            if current_phrase:
                phrases.append(" ".join(current_phrase))
                current_phrase = []
            phrases.append(';')

    if current_phrase:
        phrases.append(" ".join(current_phrase))

    return phrases

# %%
import sqlite3

conn = sqlite3.connect('/content/full_products_database.db')
cursor = conn.cursor()

# добавляем новую колонку
cursor.execute('''
    ALTER TABLE merged_table ADD COLUMN composition_tokenized TEXT
''')
conn.commit()

# очищаем текст
def process_composition_text(composition_text):
    composition_text = re.sub(r'[()\/]', ' ', composition_text)
    doc = nlp(composition_text)

    normalized_tokens = normalize_tokens(doc)
    phrases = join_tokens_into_phrases(normalized_tokens)

    return ''.join(phrases)

def process_database():
    cursor.execute('SELECT itemId, composition FROM merged_table')
    rows = cursor.fetchall()

    product_counter = 1

    for item_id, composition in rows:
        print(f"Токенизация состава для продукта #{product_counter} (ID: {item_id})...")
        if composition:
            tokenized_composition = process_composition_text(composition)

            cursor.execute('''
                UPDATE merged_table
                SET composition_tokenized = ?
                WHERE itemId = ?
            ''', (tokenized_composition, item_id))
        product_counter += 1

    conn.commit()
    conn.close()

process_database()
save_data()
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Синонимы для polysorbate найдены в кэше.
# Синонимы для 20 найдены в кэше.
# Синонимы для caprylic найдены в кэше.
# Синонимы для capric найдены в кэше.
# Синонимы для triglyceride найдены в кэше.
# Синонимы для arginine найдены в кэше.
# Синонимы для dipotassium найдены в кэше.
# Синонимы для glycyrrhizate найдены в кэше.
# Синонимы для hydroxyacetophenone найдены в кэше.
# Синонимы для 1,2-hexanediol найдены в кэше.
# Синонимы для ethylhexylglycerin найдены в кэше.
# Синонимы для disodium найдены в кэше.
# Синонимы для edta найдены в кэше.
# Токенизация состава для продукта #4206 (ID: 19000187279)...
# Синонимы для water найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для propanediol найдены в кэше.
# Синонимы для butylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для 1,2-hexanediol найдены в кэше.
# Синонимы для niacinamide найдены в кэше.
# Синонимы для prunus найдены в кэше.
# Синонимы для cerasus найдены в кэше.
# Синонимы для bitter найдены в кэше.
# Синонимы для cherry найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для c12 найдены в кэше.
# Синонимы для 14 найдены в кэше.
# Синонимы для alketh-12 найдены в кэше.
# Синонимы для macadamia найдены в кэше.
# Синонимы для ternifolia найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для arginine найдены в кэше.
# Синонимы для carbomer найдены в кэше.
# Синонимы для allantoin найдены в кэше.
# Синонимы для ammonium найдены в кэше.
# Синонимы для acryloyldimethyltaurate найдены в кэше.
# Синонимы для vp найдены в кэше.
# Синонимы для copolymer найдены в кэше.
# Синонимы для hibiscus найдены в кэше.
# Синонимы для sabdariffa найдены в кэше.
# Синонимы для flower найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для brassica найдены в кэше.
# Синонимы для campestris найдены в кэше.
# Синонимы для rapeseed найдены в кэше.
# Синонимы для sterols найдены в кэше.
# Синонимы для cholesterol найдены в кэше.
# Синонимы для phytosteryl найдены в кэше.
# Синонимы для behenyl найдены в кэше.
# Синонимы для octyldodecyl найдены в кэше.
# Синонимы для lauroyl найдены в кэше.
# Синонимы для glutamate найдены в кэше.
# Синонимы для polyglyceryl-10 найдены в кэше.
# Синонимы для oleate найдены в кэше.
# Синонимы для melatonin найдены в кэше.
# Синонимы для adenosine найдены в кэше.
# Синонимы для hydrogenated найдены в кэше.
# Синонимы для lecithin найдены в кэше.
# Синонимы для disodium найдены в кэше.
# Синонимы для edta найдены в кэше.
# Синонимы для xanthan найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для pyrus найдены в кэше.
# Синонимы для communis найдены в кэше.
# Синонимы для pear найдены в кэше.
# Синонимы для fruit найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для hydrolyzed найдены в кэше.
# Синонимы для pea найдены в кэше.
# Синонимы для protein найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для hyaluronate найдены в кэше.
# Синонимы для hedera найдены в кэше.
# Синонимы для helix найдены в кэше.
# Синонимы для ivy найдены в кэше.
# Синонимы для stem найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для phytosterols найдены в кэше.
# Синонимы для lecithin найдены в кэше.
# Синонимы для olea найдены в кэше.
# Синонимы для europaea найдены в кэше.
# Синонимы для olive найдены в кэше.
# Синонимы для fruit найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для squalane найдены в кэше.
# Синонимы для bifida найдены в кэше.
# Синонимы для ferment найдены в кэше.
# Синонимы для filtrate найдены в кэше.
# Синонимы для lactobacillus найдены в кэше.
# Синонимы для ferment найдены в кэше.
# Синонимы для lactococcus найдены в кэше.
# Синонимы для ferment найдены в кэше.
# Синонимы для lysate найдены в кэше.
# Синонимы для streptococcus найдены в кэше.
# Синонимы для thermophilus найдены в кэше.
# Синонимы для ferment найдены в кэше.
# Синонимы для fragaria найдены в кэше.
# Синонимы для chiloensis найдены в кэше.
# Синонимы для strawberry найдены в кэше.
# Синонимы для fruit найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для melia найдены в кэше.
# Синонимы для azadirachta найдены в кэше.
# Синонимы для flower найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для melia найдены в кэше.
# Синонимы для azadirachta найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для pyrus найдены в кэше.
# Синонимы для malus найдены в кэше.
# Синонимы для apple найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для betaine найдены в кэше.
# Синонимы для butyrospermum найдены в кэше.
# Синонимы для parkii найдены в кэше.
# Синонимы для shea найдены в кэше.
# Синонимы для butter найдены в кэше.
# Синонимы для ceramide найдены в кэше.
# Синонимы для np найдены в кэше.
# Синонимы для caprylic найдены в кэше.
# Синонимы для capric найдены в кэше.
# Синонимы для triglyceride найдены в кэше.
# Синонимы для coccinia найдены в кэше.
# Синонимы для indica найдены в кэше.
# Синонимы для fruit найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для corallina найдены в кэше.
# Синонимы для officinalis найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для astaxanthin найдены в кэше.
# Токенизация состава для продукта #4207 (ID: 19000187280)...
# Синонимы для collagen найдены в кэше.
# Синонимы для water найдены в кэше.
# Синонимы для 710,000ppm найдены в кэше.
# Синонимы для caprylic найдены в кэше.
# Синонимы для capric найдены в кэше.
# Синонимы для triglyceride найдены в кэше.
# Синонимы для dipropylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для 1,2-hexanediol найдены в кэше.
# Синонимы для coco-caprylate найдены в кэше.
# Синонимы для caprate найдены в кэше.
# Синонимы для macadamia найдены в кэше.
# Синонимы для ternifolia найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для niacinamide найдены в кэше.
# Синонимы для triethyl найдены в кэше.
# Синонимы для citrate найдены в кэше.
# Синонимы для water найдены в кэше.
# Синонимы для lithospermum найдены в кэше.
# Синонимы для erythrorhizon найдены в кэше.
# Синонимы для root найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для leontopodium найдены в кэше.
# Синонимы для alpinum найдены в кэше.
# Синонимы для callus найдены в кэше.
# Синонимы для culture найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для adenosine найдены в кэше.
# Синонимы для butylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для disodium найдены в кэше.
# Синонимы для edta найдены в кэше.
# Синонимы для panthenol найдены в кэше.
# Синонимы для centella найдены в кэше.
# Синонимы для asiatica найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для soluble найдены в кэше.
# Синонимы для collagen найдены в кэше.
# Синонимы для 10ppm найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для hyaluronate найдены в кэше.
# Синонимы для mannose найдены в кэше.
# Синонимы для stearic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для ceramide найдены в кэше.
# Синонимы для np найдены в кэше.
# Синонимы для hyaluronic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для hydrolyzed найдены в кэше.
# Синонимы для hyaluronic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для hydroxypropyltrimonium найдены в кэше.
# Синонимы для hyaluronate найдены в кэше.
# Синонимы для potassium найдены в кэше.
# Синонимы для hyaluronate найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для hyaluronate найдены в кэше.
# Синонимы для crosspolymer найдены в кэше.
# Синонимы для glucose найдены в кэше.
# Синонимы для hydrogenated найдены в кэше.
# Синонимы для lecithin найдены в кэше.
# Синонимы для glyceryl найдены в кэше.
# Синонимы для stearate найдены в кэше.
# Синонимы для pentylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для cholesterol найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для acetylated найдены в кэше.
# Синонимы для hyaluronate найдены в кэше.
# Синонимы для ceramide найдены в кэше.
# Синонимы для ns найдены в кэше.
# Синонимы для ceramide найдены в кэше.
# Синонимы для ap найдены в кэше.
# Синонимы для ceramide найдены в кэше.
# Синонимы для as найдены в кэше.
# Синонимы для ceramide найдены в кэше.
# Синонимы для eop найдены в кэше.
# Токенизация состава для продукта #4208 (ID: 19000193683)...
# Синонимы для aqua найдены в кэше.
# Синонимы для water найдены в кэше.
# Синонимы для eau найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для coco-caprylate найдены в кэше.
# Синонимы для caprate найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для simmondsia найдены в кэше.
# Синонимы для chinensis найдены в кэше.
# Синонимы для jojoba найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для squalane найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для vitis найдены в кэше.
# Синонимы для vinifera найдены в кэше.
# Синонимы для grape найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для anthemis найдены в кэше.
# Синонимы для nobilis найдены в кэше.
# Синонимы для flower найдены в кэше.
# Синонимы для water найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для pentylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для propylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для chloride найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для aphloia найдены в кэше.
# Синонимы для theiformis найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для borago найдены в кэше.
# Синонимы для officinalis найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для camelina найдены в кэше.
# Синонимы для sativa найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для parfum найдены в кэше.
# Синонимы для fragrance найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для inositol найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для hydroxyacetophenone найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для pyrus найдены в кэше.
# Синонимы для malus найдены в кэше.
# Синонимы для apple найдены в кэше.
# Синонимы для fruit найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для hyaluronate найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для syringa найдены в кэше.
# Синонимы для vulgaris найдены в кэше.
# Синонимы для lilac найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для 1,2-hexanediol найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для caprylyl найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для niacinamide найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для tocopheryl найдены в кэше.
# Синонимы для acetate найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для caprylyl найдены в кэше.
# Синонимы для capryl найдены в кэше.
# Синонимы для glucoside найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для hydroxide найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для linalool найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для geraniol найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для citric найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для potassium найдены в кэше.
# Синонимы для sorbate найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для xanthan найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для • найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для benzoate найдены в кэше.
# Токенизация состава для продукта #4209 (ID: 19000193785)...
# Синонимы для aqua найдены в кэше.
# Синонимы для propylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для niacinamide найдены в кэше.
# Синонимы для panthenol найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для hyaluronate найдены в кэше.
# Синонимы для retinol найдены в кэше.
# Синонимы для tocopheryl найдены в кэше.
# Синонимы для acetate найдены в кэше.
# Синонимы для linoleic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для retinyl найдены в кэше.
# Синонимы для palmitate найдены в кэше.
# Синонимы для phenoxyethanol найдены в кэше.
# Синонимы для lecithin найдены в кэше.
# Синонимы для carnitine найдены в кэше.
# Синонимы для ubiquinone найдены в кэше.
# Синонимы для ethylhexylglycerin найдены в кэше.
# Синонимы для polysorbate найдены в кэше.
# Синонимы для 20 найдены в кэше.
# Синонимы для chamomilla найдены в кэше.
# Синонимы для recutita найдены в кэше.
# Синонимы для matricaria найдены в кэше.
# Синонимы для flower найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для peg-20 найдены в кэше.
# Синонимы для glyceryl найдены в кэше.
# Синонимы для laurate найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для acrylates найдены в кэше.
# Синонимы для c10 найдены в кэше.
# Синонимы для 30 найдены в кэше.
# Синонимы для alkyl найдены в кэше.
# Синонимы для acrylate найдены в кэше.
# Синонимы для crosspolymer найдены в кэше.
# Синонимы для disodium найдены в кэше.
# Синонимы для edta найдены в кэше.
# Синонимы для potassium найдены в кэше.
# Синонимы для sorbate найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для benzoate найдены в кэше.
# Синонимы для aminomethyl найдены в кэше.
# Синонимы для propanol найдены в кэше.
# Синонимы для parfum найдены в кэше.
# Синонимы для linalool найдены в кэше.
# Токенизация состава для продукта #4210 (ID: 19000194441)...
# Синонимы для water найдены в кэше.
# Синонимы для aqua найдены в кэше.
# Синонимы для argania найдены в кэше.
# Синонимы для spinosa найдены в кэше.
# Синонимы для kernel найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для isoamyl найдены в кэше.
# Синонимы для laurate найдены в кэше.
# Синонимы для glyceryl найдены в кэше.
# Синонимы для stearate найдены в кэше.
# Синонимы для citrate найдены в кэше.
# Синонимы для coco-caprylate найдены в кэше.
# Синонимы для leuconostoc найдены в кэше.
# Синонимы для radish найдены в кэше.
# Синонимы для root найдены в кэше.
# Синонимы для ferment найдены в кэше.
# Синонимы для filtrate найдены в кэше.
# Синонимы для theobroma найдены в кэше.
# Синонимы для cacao найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для butter найдены в кэше.
# Синонимы для lactobacillus найдены в кэше.
# Синонимы для polyglyceryl-3 найдены в кэше.
# Синонимы для stearate найдены в кэше.
# Синонимы для coconut найдены в кэше.
# Синонимы для alkanes найдены в кэше.
# Синонимы для hydrogenated найдены в кэше.
# Синонимы для lecithin найдены в кэше.
# Синонимы для betaine найдены в кэше.
# Синонимы для parfum найдены в кэше.
# Синонимы для fragrance найдены в кэше.
# Синонимы для cocos найдены в кэше.
# Синонимы для nucifera найдены в кэше.
# Синонимы для fruit найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для hydrolyzed найдены в кэше.
# Синонимы для pea найдены в кэше.
# Синонимы для protein найдены в кэше.
# Синонимы для acacia найдены в кэше.
# Синонимы для senegal найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для xanthan найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для tocopherol найдены в кэше.
# Синонимы для theobroma найдены в кэше.
# Синонимы для cacao найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для ascorbyl найдены в кэше.
# Синонимы для glucosid найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для hyaluronate найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для hydrolyzed найдены в кэше.
# Синонимы для wheat найдены в кэше.
# Синонимы для protein найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для benzoate найдены в кэше.
# Синонимы для potassium найдены в кэше.
# Синонимы для sorbate найдены в кэше.
# Токенизация состава для продукта #4211 (ID: 19000194714)...
# Синонимы для aqua найдены в кэше.
# Синонимы для water найдены в кэше.
# Синонимы для glyceryl найдены в кэше.
# Синонимы для stearate найдены в кэше.
# Синонимы для hydrogenated найдены в кэше.
# Синонимы для polyisobutene найдены в кэше.
# Синонимы для octyldodecanol найдены в кэше.
# Синонимы для cetearyl найдены в кэше.
# Синонимы для alcohol найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для ceteareth-20 найдены в кэше.
# Синонимы для ceteareth-12 найдены в кэше.
# Синонимы для polyacrylamide найдены в кэше.
# Синонимы для phenoxyethanol найдены в кэше.
# Синонимы для dimethicone найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для pca найдены в кэше.
# Синонимы для c13 найдены в кэше.
# Синонимы для 14 найдены в кэше.
# Синонимы для isoparaffin найдены в кэше.
# Синонимы для xanthan найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для allantoin найдены в кэше.
# Синонимы для caprylyl найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для chlorphenesin найдены в кэше.
# Синонимы для laureth-7 найдены в кэше.
# Синонимы для cyamopsis найдены в кэше.
# Синонимы для tetragonoloba найдены в кэше.
# Синонимы для guar найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для parfum найдены в кэше.
# Синонимы для fragrance найдены в кэше.
# Синонимы для aloe найдены в кэше.
# Синонимы для barbadensis найдены в кэше.
# Синонимы для juice найдены в кэше.
# Синонимы для powder найдены в кэше.
# Синонимы для citric найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для citrate найдены в кэше.
# Синонимы для soluble найдены в кэше.
# Синонимы для collagen найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для benzoate найдены в кэше.
# Синонимы для benzyl найдены в кэше.
# Синонимы для salicylate найдены в кэше.
# Синонимы для linalool найдены в кэше.
# Синонимы для hexyl найдены в кэше.
# Синонимы для cinnamal найдены в кэше.
# Синонимы для citronellol найдены в кэше.
# Токенизация состава для продукта #4212 (ID: 19000197435)...
# Синонимы для aqua найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для pentylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для peg-60 найдены в кэше.
# Синонимы для almond найдены в кэше.
# Синонимы для glycerides найдены в кэше.
# Синонимы для inulin найдены в кэше.
# Синонимы для polyacrylate найдены в кэше.
# Синонимы для crosspolymer-6 найдены в кэше.
# Синонимы для hydrolyzed найдены в кэше.
# Синонимы для caesalpinia найдены в кэше.
# Синонимы для spinosa найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для hyaluronic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для caesalpinia найдены в кэше.
# Синонимы для spinosa найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для panthenol найдены в кэше.
# Синонимы для centella найдены в кэше.
# Синонимы для asiatica найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для hydrolyzed найдены в кэше.
# Синонимы для rice найдены в кэше.
# Синонимы для protein найдены в кэше.
# Синонимы для decylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для o-cymen-5-ol найдены в кэше.
# Синонимы для alpha-glucan найдены в кэше.
# Синонимы для oligosaccharide найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для benzoate найдены в кэше.
# Синонимы для potassium найдены в кэше.
# Синонимы для sorbate найдены в кэше.
# Синонимы для triethanolamine найдены в кэше.
# Синонимы для parfum найдены в кэше.
# Синонимы для ingredients найдены в кэше.
# Синонимы для of найдены в кэше.
# Синонимы для natural найдены в кэше.
# Синонимы для origin найдены в кэше.
# Токенизация состава для продукта #4213 (ID: 19000197436)...
# Синонимы для aqua найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для lecithin найдены в кэше.
# Синонимы для sorbitol найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для ascorbyl найдены в кэше.
# Синонимы для phosphate найдены в кэше.
# Синонимы для biosaccharide найдены в кэше.
# Синонимы для gum-1 найдены в кэше.
# Синонимы для medicago найдены в кэше.
# Синонимы для sativia найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для phenoxyetanol найдены в кэше.
# Синонимы для methylparaben найдены в кэше.
# Синонимы для ethylparaben найдены в кэше.
# Синонимы для propylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для peg-7 найдены в кэше.
# Синонимы для glyceryl найдены в кэше.
# Синонимы для cocoate найдены в кэше.
# Синонимы для imidazolidinyl найдены в кэше.
# Синонимы для urea найдены в кэше.
# Синонимы для xanthan найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для disodium найдены в кэше.
# Синонимы для edta найдены в кэше.
# Токенизация состава для продукта #4214 (ID: 19000197443)...
# Синонимы для aqua найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для peg-60 найдены в кэше.
# Синонимы для almond найдены в кэше.
# Синонимы для glycerides найдены в кэше.
# Синонимы для chondrus найдены в кэше.
# Синонимы для crispus найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для hydrolyzed найдены в кэше.
# Синонимы для caesalpinia найдены в кэше.
# Синонимы для spinosa найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для caesalpinia найдены в кэше.
# Синонимы для spinosa найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для lecithin найдены в кэше.
# Синонимы для sorbitol найдены в кэше.
# Синонимы для xanthan найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для ascorbyl найдены в кэше.
# Синонимы для phosphate найдены в кэше.
# Синонимы для hyaluronic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для acetyl найдены в кэше.
# Синонимы для octapeptide-3 найдены в кэше.
# Синонимы для hydrolyzed найдены в кэше.
# Синонимы для rice найдены в кэше.
# Синонимы для protein найдены в кэше.
# Синонимы для pentylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для lactic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для caprylyl найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для glyceryl найдены в кэше.
# Синонимы для caprylate найдены в кэше.
# Синонимы для potassium найдены в кэше.
# Синонимы для sorbate найдены в кэше.
# Синонимы для imidazolidinyl найдены в кэше.
# Синонимы для urea найдены в кэше.
# Синонимы для methylparaben найдены в кэше.
# Синонимы для phenoxyethanol найдены в кэше.
# Синонимы для parfum найдены в кэше.
# Синонимы для disodium найдены в кэше.
# Синонимы для edta найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для sulfate найдены в кэше.
# Синонимы для ci найдены в кэше.
# Синонимы для 42090 найдены в кэше.
# Токенизация состава для продукта #4215 (ID: 19000197452)...
# Синонимы для aqua найдены в кэше.
# Синонимы для propylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для isopentyldiol найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для dipropylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для pentylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для caffeine найдены в кэше.
# Синонимы для panthenol найдены в кэше.
# Синонимы для euphrasia найдены в кэше.
# Синонимы для oficinalis найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для aesculus найдены в кэше.
# Синонимы для hippocastanum найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для ulva найдены в кэше.
# Синонимы для lactuca найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для inulin найдены в кэше.
# Синонимы для cellulose найдены в кэше.
# Синонимы для glucose найдены в кэше.
# Синонимы для fructose найдены в кэше.
# Синонимы для cellulose найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для xanthan найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для butylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для ethylhexylglicerin найдены в кэше.
# Синонимы для caprylhydroxamic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Токенизация состава для продукта #4216 (ID: 19000200763)...
# Синонимы для hippophae найдены в кэше.
# Синонимы для rhamnoides найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для 69 найдены в кэше.
# Синонимы для % найдены в кэше.
# Синонимы для ascorbic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для 3-o-ethyl найдены в кэше.
# Синонимы для ascorbic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для niacinamide найдены в кэше.
# Синонимы для 1,2-hexanediol найдены в кэше.
# Синонимы для water найдены в кэше.
# Синонимы для limnanthes найдены в кэше.
# Синонимы для alba найдены в кэше.
# Синонимы для meadowfoam найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для dipropylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для butylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для phenyl найдены в кэше.
# Синонимы для trimethicone найдены в кэше.
# Синонимы для cetyl найдены в кэше.
# Синонимы для alcohol найдены в кэше.
# Синонимы для polymethyl найдены в кэше.
# Синонимы для methacrylate найдены в кэше.
# Синонимы для xanthan найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для glyceryl найдены в кэше.
# Синонимы для stearate найдены в кэше.
# Синонимы для cetearyl найдены в кэше.
# Синонимы для olivate найдены в кэше.
# Синонимы для polyglyceryl-10 найдены в кэше.
# Синонимы для stearate найдены в кэше.
# Синонимы для sorbitan найдены в кэше.
# Синонимы для olivate найдены в кэше.
# Синонимы для hydroxyacetophenone найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для acrylate найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для acryloyldimethyl найдены в кэше.
# Синонимы для taurate найдены в кэше.
# Синонимы для copolymer найдены в кэше.
# Синонимы для stearyl найдены в кэше.
# Синонимы для alcohol найдены в кэше.
# Синонимы для isohexadecane найдены в кэше.
# Синонимы для propylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для curcumin найдены в кэше.
# Синонимы для maltitol найдены в кэше.
# Синонимы для adenosine найдены в кэше.
# Синонимы для caprylyl найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для disodium найдены в кэше.
# Синонимы для edta найдены в кэше.
# Синонимы для myristyl найдены в кэше.
# Синонимы для alcohol найдены в кэше.
# Синонимы для polyglyceryl-4 найдены в кэше.
# Синонимы для oleate найдены в кэше.
# Синонимы для phellodendron найдены в кэше.
# Синонимы для amurense найдены в кэше.
# Синонимы для bark найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для astragalus найдены в кэше.
# Синонимы для membranaceus найдены в кэше.
# Синонимы для root найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для scutellaria найдены в кэше.
# Синонимы для baicalensis найдены в кэше.
# Синонимы для root найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для coptis найдены в кэше.
# Синонимы для chinensis найдены в кэше.
# Синонимы для root найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для dimethicone найдены в кэше.
# Синонимы для pentylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для tocopherol найдены в кэше.
# Синонимы для lauryl найдены в кэше.
# Синонимы для alcohol найдены в кэше.
# Синонимы для hydrogenated найдены в кэше.
# Синонимы для lecithin найдены в кэше.
# Синонимы для phytosterols найдены в кэше.
# Синонимы для sorbitan найдены в кэше.
# Синонимы для oleate найдены в кэше.
# Синонимы для linoleic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для madecassoside найдены в кэше.
# Синонимы для glycine найдены в кэше.
# Синонимы для soja найдены в кэше.
# Синонимы для soybean найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для thiamine найдены в кэше.
# Синонимы для hci найдены в кэше.
# Синонимы для arbutin найдены в кэше.
# Синонимы для glutathione найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для ascorbate найдены в кэше.
# Синонимы для retinol найдены в кэше.
# Синонимы для dipotassium найдены в кэше.
# Синонимы для glycyrrhizate найдены в кэше.
# Синонимы для fragrance найдены в кэше.
# Токенизация состава для продукта #4217 (ID: 19000204446)...
# Синонимы для aqua найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для glycolic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для saccharide найдены в кэше.
# Синонимы для isomerate найдены в кэше.
# Синонимы для salicylic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для pca найдены в кэше.
# Синонимы для polysorbate найдены в кэше.
# Синонимы для 20 найдены в кэше.
# Синонимы для pentylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для hyaluronate найдены в кэше.
# Синонимы для hyaluronic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для lactc найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для maliċ найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для panthenol найдены в кэше.
# Синонимы для provitamin найдены в кэше.
# Синонимы для b5 найдены в кэше.
# Синонимы для tocopheryl найдены в кэше.
# Синонимы для acetate найдены в кэше.
# Синонимы для e найдены в кэше.
# Синонимы для phenoxyethanol найдены в кэше.
# Синонимы для ethylhexylglycerin найдены в кэше.
# Синонимы для xanthan найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для acrylates найдены в кэше.
# Синонимы для c10 найдены в кэше.
# Синонимы для 30 найдены в кэше.
# Синонимы для alkyl найдены в кэше.
# Синонимы для acrylate найдены в кэше.
# Синонимы для crosspolymer найдены в кэше.
# Синонимы для parfum найдены в кэше.
# Синонимы для citric найдены в кэше.
# Синонимы для acid найдены в кэше.
# Токенизация состава для продукта #4218 (ID: 19000205650)...
# Синонимы для aqua найдены в кэше.
# Синонимы для palmitoyl найдены в кэше.
# Синонимы для tetrapeptide-72 найдены в кэше.
# Синонимы для amide найдены в кэше.
# Синонимы для betaine найдены в кэше.
# Синонимы для butylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для phenoxyethanol найдены в кэше.
# Синонимы для xanthan найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для hyaluronate найдены в кэше.
# Синонимы для ethylhexylglycerin найдены в кэше.
# Синонимы для pentylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для citric найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для chenopodium найдены в кэше.
# Синонимы для quinoa найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для oryza найдены в кэше.
# Синонимы для sativa найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для glycine найдены в кэше.
# Синонимы для max найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для panax найдены в кэше.
# Синонимы для ginseng найдены в кэше.
# Синонимы для root найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для daucus найдены в кэше.
# Синонимы для carota найдены в кэше.
# Синонимы для sativa найдены в кэше.
# Синонимы для root найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для nicotiana найдены в кэше.
# Синонимы для benthamiana найдены в кэше.
# Синонимы для hexapeptide-40 найдены в кэше.
# Синонимы для sh-polypeptide-47 найдены в кэше.
# Токенизация состава для продукта #4219 (ID: 19000206431)...
# Синонимы для water найдены в кэше.
# Синонимы для dipropylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для caffeine найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для niacinamide найдены в кэше.
# Синонимы для glycereth-26 найдены в кэше.
# Синонимы для 1,2-hexanediol найдены в кэше.
# Синонимы для xanthan найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для c12 найдены в кэше.
# Синонимы для 14 найдены в кэше.
# Синонимы для pareth-12 найдены в кэше.
# Синонимы для polyglyceryl-10 найдены в кэше.
# Синонимы для diisostearate найдены в кэше.
# Синонимы для hydroxyacetophenone найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для naphthalenesulfonate найдены в кэше.
# Синонимы для c12 найдены в кэше.
# Синонимы для 13 найдены в кэше.
# Синонимы для pareth-9 найдены в кэше.
# Синонимы для caprylyl найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для adenosine найдены в кэше.
# Синонимы для disodium найдены в кэше.
# Синонимы для edta найдены в кэше.
# Синонимы для hyaluronic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для dextrin найдены в кэше.
# Синонимы для theobroma найдены в кэше.
# Синонимы для cacao найдены в кэше.
# Синонимы для cocoa найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для panthenol найдены в кэше.
# Синонимы для butylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для ethylhexylglycerin найдены в кэше.
# Синонимы для dipotassium найдены в кэше.
# Синонимы для glycyrrhizate найдены в кэше.
# Синонимы для resveratrol найдены в кэше.
# Токенизация состава для продукта #4220 (ID: 19000210490)...
# Синонимы для aqua найдены в кэше.
# Синонимы для aloe найдены в кэше.
# Синонимы для barbadensis найдены в кэше.
# Синонимы для juice найдены в кэше.
# Синонимы для sambucus найдены в кэше.
# Синонимы для nigra найдены в кэше.
# Синонимы для fruit найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для glycolic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для mandelic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для aesculus найдены в кэше.
# Синонимы для hippocastanum найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для lactic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для panthenol найдены в кэше.
# Синонимы для salicylic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для hyaluronate найдены в кэше.
# Синонимы для tocopheryl найдены в кэше.
# Синонимы для acetate найдены в кэше.
# Синонимы для mangifera найдены в кэше.
# Синонимы для indica найдены в кэше.
# Синонимы для pulp найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для musa найдены в кэше.
# Синонимы для sapientum найдены в кэше.
# Синонимы для pulp найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для spondias найдены в кэше.
# Синонимы для mombin найдены в кэше.
# Синонимы для pulp найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для glyceryl найдены в кэше.
# Синонимы для caprylate найдены в кэше.
# Синонимы для glyceryl найдены в кэше.
# Синонимы для undecylenate найдены в кэше.
# Синонимы для cananga найдены в кэше.
# Синонимы для odorata найдены в кэше.
# Синонимы для flower найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для citrus найдены в кэше.
# Синонимы для bergamia найдены в кэше.
# Синонимы для peel найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для expressed найдены в кэше.
# Синонимы для matricaria найдены в кэше.
# Синонимы для recutita найдены в кэше.
# Синонимы для flower найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для xanthan найдены в кэше.
# Синонимы для gum найдены в кэше.
# Токенизация состава для продукта #4221 (ID: 19000210492)...
# Синонимы для rosa найдены в кэше.
# Синонимы для canina найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для ozonized найдены в кэше.
# Синонимы для argan найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для vitis найдены в кэше.
# Синонимы для vinifera найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для borago найдены в кэше.
# Синонимы для officinalis найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для carthamus найдены в кэше.
# Синонимы для tinctorius найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для coffea найдены в кэше.
# Синонимы для arabica найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для macadamia найдены в кэше.
# Синонимы для ternifolia найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для simmondsia найдены в кэше.
# Синонимы для chinensis найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для hypericum найдены в кэше.
# Синонимы для perforatum найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для adansonia найдены в кэше.
# Синонимы для digitata найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для tocopheryl найдены в кэше.
# Синонимы для acetate найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для citrus найдены в кэше.
# Синонимы для sinensis найдены в кэше.
# Синонимы для peel найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для expressed найдены в кэше.
# Синонимы для boswellia найдены в кэше.
# Синонимы для serrata найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для ascorbyl найдены в кэше.
# Синонимы для tetraisopalmitate найдены в кэше.
# Синонимы для cananga найдены в кэше.
# Синонимы для odorata найдены в кэше.
# Синонимы для flower найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для canarium найдены в кэше.
# Синонимы для luzonicum найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для pelargonium найдены в кэше.
# Синонимы для graveolens найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для retinyl найдены в кэше.
# Синонимы для palmitate найдены в кэше.
# Синонимы для vanilla найдены в кэше.
# Синонимы для planifolia найдены в кэше.
# Синонимы для fruit найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для vetiveria найдены в кэше.
# Синонимы для zizanoides найдены в кэше.
# Синонимы для root найдены в кэше.
# Синонимы для oil найдены в кэше.
# Токенизация состава для продукта #4222 (ID: 19000210494)...
# Синонимы для carthamus найдены в кэше.
# Синонимы для tinctorius найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для borago найдены в кэше.
# Синонимы для officinalis найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для macadamia найдены в кэше.
# Синонимы для ternifolia найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для simmondsia найдены в кэше.
# Синонимы для chinensis найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для calophyllum найдены в кэше.
# Синонимы для inophyllum найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для vitis найдены в кэше.
# Синонимы для vinifera найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для nigella найдены в кэше.
# Синонимы для sativa найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для oryza найдены в кэше.
# Синонимы для sativa найдены в кэше.
# Синонимы для bran найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для tocopheryl найдены в кэше.
# Синонимы для acetate найдены в кэше.
# Синонимы для lavandula найдены в кэше.
# Синонимы для angustifolia найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для matricaria найдены в кэше.
# Синонимы для recutita найдены в кэше.
# Синонимы для flower найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для ascorbyl найдены в кэше.
# Синонимы для tetraisopalmitate найдены в кэше.
# Синонимы для melaleuca найдены в кэше.
# Синонимы для alternifolia найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для pelargonium найдены в кэше.
# Синонимы для graveolens найдены в кэше.
# Синонимы для oil найдены в кэше.
# Токенизация состава для продукта #4223 (ID: 19000210540)...
# Синонимы для water найдены в кэше.
# Синонимы для butylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для niacinamide найдены в кэше.
# Синонимы для 20 найдены в кэше.
# Синонимы для % найдены в кэше.
# Синонимы для aloe найдены в кэше.
# Синонимы для barbadensis найдены в кэше.
# Синонимы для polysaccharide найдены в кэше.
# Синонимы для polyglycerin-3 найдены в кэше.
# Синонимы для propanediol найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для 1,2-hexanediol найдены в кэше.
# Синонимы для trehalose найдены в кэше.
# Синонимы для allantoin найдены в кэше.
# Синонимы для boswellia найдены в кэше.
# Синонимы для serrata найдены в кэше.
# Синонимы для resin найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для polyacrylate найдены в кэше.
# Синонимы для paeonia найдены в кэше.
# Синонимы для seffruticosa найдены в кэше.
# Синонимы для root найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для ethylhexylglycerin найдены в кэше.
# Синонимы для zinc найдены в кэше.
# Синонимы для pca найдены в кэше.
# Синонимы для ectoin найдены в кэше.
# Токенизация состава для продукта #4224 (ID: 19000212327)...
# Синонимы для propanediol найдены в кэше.
# Синонимы для ascorbic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для ethyl найдены в кэше.
# Синонимы для ascorbyl найдены в кэше.
# Синонимы для ether найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для dipropylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для pentylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для butylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для potassium найдены в кэше.
# Синонимы для hydroxide найдены в кэше.
# Синонимы для madecassoside найдены в кэше.
# Синонимы для glutathione найдены в кэше.
# Синонимы для ferulic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для carnitine найдены в кэше.
# Синонимы для pyridoxine найдены в кэше.
# Синонимы для biotin найдены в кэше.
# Синонимы для inositol найдены в кэше.
# Синонимы для folic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для tocopherol найдены в кэше.
# Токенизация состава для продукта #4225 (ID: 19000212394)...
# Синонимы для mineral найдены в кэше.
# Синонимы для water найдены в кэше.
# Синонимы для propanediol найдены в кэше.
# Синонимы для isopentyldiol найдены в кэше.
# Синонимы для butylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для methylpropanediol найдены в кэше.
# Синонимы для pentylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для 1,2-hexanediol найдены в кэше.
# Синонимы для niacinamide найдены в кэше.
# Синонимы для gardenia найдены в кэше.
# Синонимы для flower найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для salvia найдены в кэше.
# Синонимы для water найдены в кэше.
# Синонимы для centide найдены в кэше.
# Синонимы для geranium найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для centella найдены в кэше.
# Синонимы для asiatica найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для fig найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для kelp найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для nasturtium найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для cacao найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для daisy найдены в кэше.
# Синонимы для flower найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для stone найдены в кэше.
# Синонимы для bean найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для hydrogenated найдены в кэше.
# Синонимы для lecithin найдены в кэше.
# Синонимы для sentient найдены в кэше.
# Синонимы для geranium найдены в кэше.
# Синонимы для flower найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для lavender найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для pencil найдены в кэше.
# Синонимы для juniper найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для atlas найдены в кэше.
# Синонимы для cedar найдены в кэше.
# Синонимы для bark найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для balsam найдены в кэше.
# Синонимы для amiris найдены в кэше.
# Синонимы для bark найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для gwanggwak найдены в кэше.
# Синонимы для fragrance найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для rosehip найдены в кэше.
# Синонимы для fruit найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для octyldodeses-16 найдены в кэше.
# Синонимы для carbomer найдены в кэше.
# Синонимы для tromethamine найдены в кэше.
# Синонимы для ethyl найдены в кэше.
# Синонимы для ascorbyl найдены в кэше.
# Синонимы для ether найдены в кэше.
# Синонимы для hydrolyzed найдены в кэше.
# Синонимы для hyaluronic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для adenosine найдены в кэше.
# Синонимы для fructooligosaccharide найдены в кэше.
# Синонимы для diesodium найдены в кэше.
# Синонимы для edita найдены в кэше.
# Синонимы для panthenol найдены в кэше.
# Синонимы для beta-glucan найдены в кэше.
# Синонимы для 3-o-ethyl найдены в кэше.
# Синонимы для ascorbic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для ceramide найдены в кэше.
# Синонимы для np найдены в кэше.
# Синонимы для dextrin найдены в кэше.
# Синонимы для ectoin найдены в кэше.
# Синонимы для balsamco найдены в кэше.
# Синонимы для fiber найдены в кэше.
# Синонимы для resin найдены в кэше.
# Синонимы для cyanocobalamine найдены в кэше.
# Синонимы для arginine найдены в кэше.
# Синонимы для ammonium найдены в кэше.
# Синонимы для acryloyldimethyltaurate найдены в кэше.
# Синонимы для vpicopolymer найдены в кэше.
# Синонимы для tetrahydropiperine найдены в кэше.
# Синонимы для phloretin найдены в кэше.
# Синонимы для purified найдены в кэше.
# Синонимы для water найдены в кэше.
# Синонимы для ethylhexylglycerin найдены в кэше.
# Синонимы для citronellol найдены в кэше.
# Синонимы для linalool найдены в кэше.
# Синонимы для geraniol найдены в кэше.
# Токенизация состава для продукта #4226 (ID: 19000212395)...
# Синонимы для mineral найдены в кэше.
# Синонимы для water найдены в кэше.
# Синонимы для propanediol найдены в кэше.
# Синонимы для isopentyldiol найдены в кэше.
# Синонимы для butylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для methylpropanediol найдены в кэше.
# Синонимы для pentylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для 1,2-hexanediol найдены в кэше.
# Синонимы для niacinamide найдены в кэше.
# Синонимы для gardenia найдены в кэше.
# Синонимы для flower найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для salvia найдены в кэше.
# Синонимы для water найдены в кэше.
# Синонимы для centide найдены в кэше.
# Синонимы для geranium найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для centella найдены в кэше.
# Синонимы для asiatica найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для fig найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для kelp найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для nasturtium найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для cacao найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для daisy найдены в кэше.
# Синонимы для flower найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для stone найдены в кэше.
# Синонимы для bean найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для hydrogenated найдены в кэше.
# Синонимы для lecithin найдены в кэше.
# Синонимы для sentient найдены в кэше.
# Синонимы для geranium найдены в кэше.
# Синонимы для flower найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для lavender найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для pencil найдены в кэше.
# Синонимы для juniper найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для atlas найдены в кэше.
# Синонимы для cedar найдены в кэше.
# Синонимы для bark найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для balsam найдены в кэше.
# Синонимы для amiris найдены в кэше.
# Синонимы для bark найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для gwanggwak найдены в кэше.
# Синонимы для fragrance найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для rosehip найдены в кэше.
# Синонимы для fruit найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для octyldodeses-16 найдены в кэше.
# Синонимы для carbomer найдены в кэше.
# Синонимы для tromethamine найдены в кэше.
# ...
# Синонимы для propylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для hydroxide найдены в кэше.
# Синонимы для sorbitan найдены в кэше.
# 404 для компонента isosostearate по ссылке https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/isosostearate/synonyms/JSON - добавляю в список ошибок
# Синонимы для sucrose найдены в кэше.
# Синонимы для stearate найдены в кэше.
# Синонимы для xanthan найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для xanthan найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для mica найдены в кэше.
# Синонимы для titanium найдены в кэше.
# Синонимы для dioxide найдены в кэше.
# Синонимы для ci найдены в кэше.
# Синонимы для 77891 найдены в кэше.
# Синонимы для chlorphenesin найдены в кэше.
# Компонент ethylhexylglyceerin уже был с 404, пропускаем.
# Синонимы для ethylparaben найдены в кэше.
# Синонимы для methylparaben найдены в кэше.
# Синонимы для phenoxyethanol найдены в кэше.
# Компонент potass уже был с 404, пропускаем.
# Синонимы для sorbate найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для benzoate найдены в кэше.
# Синонимы для sorbic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для fragrance найдены в кэше.
# Синонимы для parfum найдены в кэше.
# Компонент alpha-simeethyl уже был с 404, пропускаем.
# Синонимы для ionone найдены в кэше.
# Синонимы для benzyl найдены в кэше.
# Синонимы для benzoate найдены в кэше.
# Синонимы для citral найдены в кэше.
# Синонимы для citronellol найдены в кэше.
# Синонимы для coumarin найдены в кэше.
# Компонент graniol уже был с 404, пропускаем.
# Синонимы для hexyl найдены в кэше.
# Синонимы для cinnamal найдены в кэше.
# Синонимы для linalool найдены в кэше.
# Токенизация состава для продукта #4277 (ID: 30022100008)...
# Синонимы для artesian найдены в кэше.
# Синонимы для water найдены в кэше.
# Компонент hydroelectric уже был с 404, пропускаем.
# Компонент hydrolyte уже был с 404, пропускаем.
# Синонимы для vegetable найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для ethyl найдены в кэше.
# Синонимы для ether найдены в кэше.
# Синонимы для of найдены в кэше.
# Синонимы для milk найдены в кэше.
# Синонимы для thistle найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для natural найдены в кэше.
# Синонимы для polysaccharide найдены в кэше.
# Синонимы для scleroglucan найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для and найдены в кэше.
# 404 для компонента cesalpinia по ссылке https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/cesalpinia/synonyms/JSON - добавляю в список ошибок
# Синонимы для gum найдены в кэше.
# Синонимы для and найдены в кэше.
# Синонимы для gluconate найдены в кэше.
# Синонимы для gluconate найдены в кэше.
# Компонент capricy уже был с 404, пропускаем.
# Компонент whim уже был с 404, пропускаем.
# Синонимы для of найдены в кэше.
# Синонимы для triglycerides найдены в кэше.
# Синонимы для and найдены в кэше.
# Компонент dimetyl уже был с 404, пропускаем.
# Компонент isosorbitis уже был с 404, пропускаем.
# Синонимы для and найдены в кэше.
# Синонимы для seeds найдены в кэше.
# Синонимы для of найдены в кэше.
# Синонимы для seeds найдены в кэше.
# 404 для компонента kunzhuta по ссылке https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/kunzhuta/synonyms/JSON - добавляю в список ошибок
# Синонимы для i найдены в кэше.
# Синонимы для of найдены в кэше.
# Синонимы для tocopherol найдены в кэше.
# Синонимы для acetate найдены в кэше.
# Синонимы для maca найдены в кэше.
# Синонимы для seeds найдены в кэше.
# 404 для компонента hine по ссылке https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/hine/synonyms/JSON - добавляю в список ошибок
# Синонимы для extract найдены в кэше.
# Синонимы для hydrolyzed найдены в кэше.
# Синонимы для collagen найдены в кэше.
# Синонимы для milk найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для milk найдены в кэше.
# Синонимы для peptides найдены в кэше.
# Синонимы для senegal найдены в кэше.
# Синонимы для acacia найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для i найдены в кэше.
# Синонимы для hydrolyzed найдены в кэше.
# Синонимы для mucopolysaccharide найдены в кэше.
# Синонимы для extracts найдены в кэше.
# Синонимы для ginseng найдены в кэше.
# Синонимы для green найдены в кэше.
# Синонимы для tea найдены в кэше.
# Синонимы для horse найдены в кэше.
# Синонимы для chestnut найдены в кэше.
# Синонимы для poppy найдены в кэше.
# Токенизация состава для продукта #4278 (ID: 30151200005)...
# Синонимы для artesian найдены в кэше.
# Синонимы для water найдены в кэше.
# Синонимы для vegetable найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для phospholipids найдены в кэше.
# Синонимы для sphingolipids найдены в кэше.
# Синонимы для plant найдены в кэше.
# Синонимы для protein найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для hyaluronate найдены в кэше.
# Синонимы для inulin найдены в кэше.
# Компонент alfa-glucan уже был с 404, пропускаем.
# Синонимы для oligosaccharide найдены в кэше.
# Синонимы для xantan найдены в кэше.
# Синонимы для gum найдены в кэше.
# 404 для компонента maclot по ссылке https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/maclot/synonyms/JSON - добавляю в список ошибок
# Синонимы для extract найдены в кэше.
# Синонимы для mimosa найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для aloe найдены в кэше.
# Синонимы для vera найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для lemon найдены в кэше.
# Синонимы для essential найдены в кэше.
# Синонимы для oil найдены в кэше.
# Токенизация состава для продукта #4279 (ID: 6760200009)...
# Синонимы для aqua найдены в кэше.
# Синонимы для water найдены в кэше.
# Компонент glyceerin уже был с 404, пропускаем.
# Синонимы для pentylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для xanthan найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для polystyrene найдены в кэше.
# Синонимы для sulfonate найдены в кэше.
# Синонимы для polysorbate найдены в кэше.
# Синонимы для 20 найдены в кэше.
# Синонимы для sorghum найдены в кэше.
# Синонимы для bicolor найдены в кэше.
# Синонимы для stalk найдены в кэше.
# Синонимы для juice найдены в кэше.
# Синонимы для levulinic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для p-anisic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для hydroxide найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для hyaluronate найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для levulinate найдены в кэше.
# Синонимы для parfum найдены в кэше.
# Синонимы для fragrance найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для benzoate найдены в кэше.
# Синонимы для citric найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для < найдены в кэше.
# Синонимы для p найдены в кэше.
# Синонимы для > найдены в кэше.
# Синонимы для partially найдены в кэше.
# Синонимы для contains найдены в кэше.
# Синонимы для the найдены в кэше.
# Синонимы для melt найдены в кэше.
# Синонимы для water найдены в кэше.
# Синонимы для of найдены в кэше.
# Синонимы для alpine найдены в кэше.
# Синонимы для glaciers найдены в кэше.
# Токенизация состава для продукта #4280 (ID: 6760200011)...
# Синонимы для aqua найдены в кэше.
# Синонимы для water найдены в кэше.
# Синонимы для propylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для methylpropanediol найдены в кэше.
# Синонимы для maltodextrin найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для polysorbate найдены в кэше.
# Синонимы для 20 найдены в кэше.
# Синонимы для caprylyl найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для acrylates найдены в кэше.
# Синонимы для c10 найдены в кэше.
# Синонимы для 30 найдены в кэше.
# Синонимы для alkyl найдены в кэше.
# Синонимы для acrylate найдены в кэше.
# Синонимы для crosspolymer найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для hyaluronate найдены в кэше.
# Синонимы для parfum найдены в кэше.
# Синонимы для fragrance найдены в кэше.
# Синонимы для phenylpropanol найдены в кэше.
# Синонимы для xanthan найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для hydroxide найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для benzoate найдены в кэше.
# Синонимы для citric найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для coenochloris найдены в кэше.
# Синонимы для signiensis найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для lecithin найдены в кэше.
# Токенизация состава для продукта #4281 (ID: 6760200012)...
# Синонимы для aqua найдены в кэше.
# Синонимы для water найдены в кэше.
# Синонимы для pentylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для methylpropanediol найдены в кэше.
# Синонимы для caprylyl найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для acrylates найдены в кэше.
# Синонимы для c10 найдены в кэше.
# Синонимы для 30 найдены в кэше.
# Синонимы для alkyl найдены в кэше.
# Синонимы для acrylate найдены в кэше.
# Синонимы для crosspolymer найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для hydroxide найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для citrate найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для citrate найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для polysorbate найдены в кэше.
# Синонимы для 20 найдены в кэше.
# Синонимы для phenylpropanol найдены в кэше.
# Синонимы для lactose найдены в кэше.
# Синонимы для lactis найдены в кэше.
# Синонимы для proteinum найдены в кэше.
# Синонимы для whey найдены в кэше.
# Синонимы для protein найдены в кэше.
# Синонимы для parfum найдены в кэше.
# Синонимы для fragrance найдены в кэше.
# Синонимы для lactic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для benzoate найдены в кэше.
# Синонимы для citric найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для partially найдены в кэше.
# Синонимы для contains найдены в кэше.
# Синонимы для the найдены в кэше.
# Синонимы для melt найдены в кэше.
# Синонимы для water найдены в кэше.
# Синонимы для of найдены в кэше.
# Синонимы для alpine найдены в кэше.
# Синонимы для glaciers найдены в кэше.
# Токенизация состава для продукта #4282 (ID: 89190500005)...
# Синонимы для avene найдены в кэше.
# Синонимы для thermal найдены в кэше.
# Синонимы для spring найдены в кэше.
# Синонимы для water найдены в кэше.
# Синонимы для avene найдены в кэше.
# Синонимы для aqua найдены в кэше.
# Синонимы для methyl найдены в кэше.
# Синонимы для gluceth-20 найдены в кэше.
# Синонимы для peg-12 найдены в кэше.
# Синонимы для cyclomethicone найдены в кэше.
# Синонимы для glycerine найдены в кэше.
# Синонимы для propylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для ceteth-3 найдены в кэше.
# Синонимы для acetate найдены в кэше.
# Синонимы для water найдены в кэше.
# Синонимы для aqua найдены в кэше.
# Синонимы для polyacrylamide найдены в кэше.
# Синонимы для alcohol найдены в кэше.
# Синонимы для benzoic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для c13 найдены в кэше.
# Синонимы для 14 найдены в кэше.
# Синонимы для isoparaffin найдены в кэше.
# Синонимы для fragrance найдены в кэше.
# Синонимы для parfum найдены в кэше.
# Синонимы для hydroxyethylcellulose найдены в кэше.
# Синонимы для laureth-7 найдены в кэше.
# Синонимы для peg найдены в кэше.
# Синонимы для ppg-18 найдены в кэше.
# Синонимы для 18 найдены в кэше.
# Синонимы для dimeticone найдены в кэше.
# Синонимы для phenoxyethanol найдены в кэше.
# Синонимы для phospholipids найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для dna найдены в кэше.
# Синонимы для tetrasodium найдены в кэше.
# Синонимы для edta найдены в кэше.
# Токенизация состава для продукта #4283 (ID: 89311400011)...
# Синонимы для aqua найдены в кэше.
# Синонимы для water найдены в кэше.
# Синонимы для hydroxyethylpiperazine найдены в кэше.
# Синонимы для ethane найдены в кэше.
# Синонимы для sulfonic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для glycolic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для alcohol найдены в кэше.
# Синонимы для denat найдены в кэше.
# Синонимы для propanediol найдены в кэше.
# Синонимы для pentylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для hydroxide найдены в кэше.
# Синонимы для citric найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для sodium найдены в кэше.
# Синонимы для hyaluronate найдены в кэше.
# Синонимы для ascorbyl найдены в кэше.
# Синонимы для glucoside найдены в кэше.
# Токенизация состава для продукта #4284 (ID: 89722900008)...
# Синонимы для anti-aging найдены в кэше.
# Синонимы для a найдены в кэше.
# Синонимы для strengthening найдены в кэше.
# Синонимы для the найдены в кэше.
# Синонимы для skin найдены в кэше.
# Синонимы для of найдены в кэше.
# Синонимы для red найдены в кэше.
# Синонимы для algae найдены в кэше.
# Синонимы для and найдены в кэше.
# Синонимы для vegan найдены в кэше.
# Синонимы для collagen найдены в кэше.
# Синонимы для restoring найдены в кэше.
# Синонимы для skin найдены в кэше.
# Синонимы для elasticity найдены в кэше.
# Токенизация состава для продукта #4285 (ID: 89970200002)...
# Синонимы для aqua найдены в кэше.
# Синонимы для dimethicone найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для xanthan найдены в кэше.
# Синонимы для gum найдены в кэше.
# Синонимы для phenoxyethanol найдены в кэше.
# Синонимы для caprylyl найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для chlorphenesin найдены в кэше.
# Синонимы для fragrance найдены в кэше.
# Синонимы для lactic найдены в кэше.
# Синонимы для acid найдены в кэше.
# Синонимы для tocopheryl найдены в кэше.
# Синонимы для acetate найдены в кэше.
# Синонимы для retinyl найдены в кэше.
# Синонимы для palmitate найдены в кэше.
# Синонимы для maris найдены в кэше.
# Синонимы для sal найдены в кэше.
# Синонимы для myrciaria найдены в кэше.
# Синонимы для dubia найдены в кэше.
# Синонимы для fruit найдены в кэше.
# Синонимы для extract найдены в кэше.
# Синонимы для maltodextrin найдены в кэше.
# Токенизация состава для продукта #4286 (ID: 9430100006)...
# Токенизация состава для продукта #4287 (ID: 9761200001)...
# Синонимы для dimethicone найдены в кэше.
# Синонимы для cyclopentasiloxane найдены в кэше.
# Синонимы для dimethicone найдены в кэше.
# Синонимы для vinyl найдены в кэше.
# Синонимы для dimethicone найдены в кэше.
# Синонимы для crosspolymer найдены в кэше.
# Синонимы для dimethicone найдены в кэше.
# Синонимы для peg-10 найдены в кэше.
# Синонимы для 15 найдены в кэше.
# Синонимы для crosspolymer найдены в кэше.
# Синонимы для dimethicone найдены в кэше.
# Синонимы для crosspolymer найдены в кэше.
# Синонимы для dipropylene найдены в кэше.
# Синонимы для glycol найдены в кэше.
# Синонимы для glycerin найдены в кэше.
# Синонимы для water найдены в кэше.
# Синонимы для phenoxyethanol найдены в кэше.
# Синонимы для citrus найдены в кэше.
# Синонимы для aurantium найдены в кэше.
# Синонимы для bergamia найдены в кэше.
# Синонимы для bergamot найдены в кэше.
# Синонимы для fruit найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для hydrogenated найдены в кэше.
# Синонимы для lecithin найдены в кэше.
# Синонимы для polyglyceryl-10 найдены в кэше.
# Синонимы для oleate найдены в кэше.
# Синонимы для adenosine найдены в кэше.
# Синонимы для hippophae найдены в кэше.
# Синонимы для rhamnoides найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для cocos найдены в кэше.
# Синонимы для nucifera найдены в кэше.
# Синонимы для coconut найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для camellia найдены в кэше.
# Синонимы для japonica найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для simmondsia найдены в кэше.
# Синонимы для chinensis найдены в кэше.
# Синонимы для jojoba найдены в кэше.
# Синонимы для seed найдены в кэше.
# Синонимы для oil найдены в кэше.
# Синонимы для prunus найдены в кэше.
# Синонимы для amygdalus найдены в кэше.
# Синонимы для dulcis найдены в кэше.
# Синонимы для sweet найдены в кэше.
# Синонимы для almond найдены в кэше.
# Синонимы для oil найдены в кэше.
# Токенизация состава для продукта #4288 (ID: 99710100014)...

# %% [markdown]
# ## Чтение таблицы сочетаний и конфликтов компонентов
#
# * С помощью `pdfplumber` извлекается таблица из PDF-файла (например, `Таблица сочетаний и конфликтов ART&FACT_.pdf` и другие).
# * Формируется `DataFrame`, где:
#    - строки и столбцы представляют различные активные ингредиенты (например, Retinol, Niacinamide),
#    - а значения на пересечении — это описание их совместимости или предупреждения (например, "не рекомендовано", "можно").
# * Далее для каждого сочетания из таблицы все возможные пары строка × столбец (с учетом синонимов) добавляются в таблицу в SQLite-базе.

# %%
# !pip install pdfplumber
import pdfplumber

# %%
with pdfplumber.open('/content/Таблица сочетаний и конфликтов ART\&FACT\_.pdf') as pdf:
page = pdf.pages[0]

table = page.extract_table()

for row in table:
print(row)

# %%
import sqlite3
import pandas as pd

# %%
# списки компонентов для колонн и рядов - активные действующие компоненты из таблицы
columns = [
'Niacinamide 2–5 %',
'Niacinamide > 5 %, nicotinamide',
'Vitamin C Ascorbic Acid ≤ 5 %, Ascorbic Acid',
'Vitamin C Ascorbic Acid > 5 % рН ≤ 4, Ascorbic Acid',
'Vitamin C, Ascorbyl Glucoside, Magnesium Ascorbyl Phosphate, 3-O-Ethyl Ascorbic Acid, Sodium Ascorbyl Phosphate, Tetrahexyldecyl Ascorbate',
'Blue Retinol Bakuchiol',
'Retinol, Retinol Acetate, Retinol Palmitate, Retinal, Retinyl Propionate, Retinol Retinoate',
'Retinol encapsulated and liposomal form',
'Azelaic Acid',
'Amino Acids + Peptides,  EGF, Matrixyl, Leuphasyl, Argireline, SYN-AKE',
'ВНА-acids,  Salicylic Acid 0.5–2 % pH = 3–4, salicylic acid, salicylic',
'AНА-acids, Lactic Acid, Glycolic Acid, Mandelic Acid 2–10 %\* рН = 3–4, cyclandelate',
'РНА-acids,  Lactobionic Acid, Gluconolactone 2–10 % pH = 3–4, Gluconolactone',
'Benzoyl Peroxide 2.5–5 %, Benzoyl Peroxide'
]

rows = [
'Niacinamide 2–5 %',
'Niacinamide > 5 %, nicotinamide',
'Vitamin C Ascorbic Acid ≤ 5 %, Ascorbic Acid',
'Vitamin C Ascorbic Acid > 5 % рН ≤ 4, Ascorbic Acid',
'Vitamin C, Ascorbyl Glucoside, Magnesium Ascorbyl Phosphate, 3-O-Ethyl Ascorbic Acid, Sodium Ascorbyl Phosphate, Tetrahexyldecyl Ascorbate',
'Blue Retinol Bakuchiol',
'Retinol, Retinol Acetate, Retinol Palmitate, Retinal, Retinyl Propionate, Retinol Retinoate',
'Retinol encapsulated and liposomal form',
'Azelaic Acid',
'Amino Acids + Peptides,  EGF, Matrixyl, Leuphasyl, Argireline, SYN-AKE',
'ВНА-acids,  Salicylic Acid 0.5–2 % pH = 3–4, salicylic acid, salicylic',
'AНА-acids, Lactic Acid, Glycolic Acid, Mandelic Acid 2–10 %\* рН = 3–4, cyclandelate',
'РНА-acids,  Lactobionic Acid, Gluconolactone 2–10 % pH = 3–4, Gluconolactone',
'Benzoyl Peroxide 2.5–5 %, Benzoyl Peroxide'
]

df = pd.DataFrame(table, columns=columns, index=rows)

# Подключение к базе данных

conn = sqlite3.connect('components-combo-3.db')
cursor = conn.cursor()

cursor.execute('''CREATE TABLE IF NOT EXISTS components (
id INTEGER PRIMARY KEY,
first_element TEXT,
second_element TEXT,
result TEXT,
comment TEXT
)''')

for i in range(len(df.index)):
  for j in range(i, len(df.columns)):
    row = df.index[i]
    col = df.columns[j]
    comment = df.at[row, col]

    # Разделяем компоненты по запятой и обрабатываем их по одному
    row_elements = [e.strip() for e in row.split(',')]
    col_elements = [e.strip() for e in col.split(',')]

    # Вставляем в базу для каждого элемента
    for r in row_elements:
        for c in col_elements:
            cursor.execute('''INSERT INTO components (first_element, second_element, result, comment)
                            VALUES (?, ?, ?, ?)''', (r, c, '', comment))

conn.commit()
conn.close()

print("Данные успешно сохранены в базу данных.")

# %% [markdown]
# ## Проверка наличия ключевых компонентов в составе продукта
#
# На этом этапе мы проверяем, содержит ли продукт один или несколько важных активных компонентов (формирование векторов характеристик), которые могут участвовать в сочетаниях или конфликтах (из предыдущего шага).
# * Каждый состав (`composition_tokenized`) разбивается по `;`, чтобы получить отдельные компоненты.
# * Для каждого элемента из списка `flags`:
#    - Ищем его точное или близкое совпадение среди токенов состава.
#    - Сохраняем результат как:
#      - `1` — есть точное совпадение,
#      - `0` — есть только похожие совпадения,
#      - `-1` — не найдено ничего подходящего.
# * В таблицу `products` добавляются новые столбцы по каждому компоненту из `flags` (названия колонок автоматически очищаются и приводятся к нижнему регистру), флаги сохраняются в базу.

# %%
import re

#функция нормализации названий компонентов, чтобы можно было назвать столбец
def normalize_ingredient_name(name):
    name = name.strip()

    name = name.replace('%', 'pct')
    name = re.sub(r'[^\w\s\-]', '', name)
    name = name.replace(' ', '_').replace('-', '_')

    # если начинается с цифры — добавим префикс (нельзя начинать имя поля в SQLite с цифры)
    if re.match(r'^\d', name):
        name = f"i_{name}"

    name = name.lower()

    return name

# %%
#создадим отдельную бд, где будут только itemId, composition_tokenized и вектора характеристик
import sqlite3

source_conn = sqlite3.connect('/content/full_products_database.db')
source_cursor = source_conn.cursor()

# Создаём новую БД
new_conn = sqlite3.connect('/content/composition_vectors.db')
new_cursor = new_conn.cursor()

new_cursor.execute('''
    CREATE TABLE IF NOT EXISTS tokenized_table (
        itemId TEXT,
        composition_tokenized TEXT
    )
''')

# Читаем данные из старой БД
try:
    source_cursor.execute("SELECT itemId, composition_tokenized FROM merged_table")
    rows = source_cursor.fetchall()
except sqlite3.DatabaseError as e:
    print("Ошибка при чтении из БД:", e)
    source_conn.close()
    new_conn.close()
    raise

# Записываем данные в новую
new_cursor.executemany('''
    INSERT INTO tokenized_table (itemId, composition_tokenized)
    VALUES (?, ?)
''', rows)

new_conn.commit()

source_conn.close()
new_conn.close()

print("Данные успешно скопированы.")

# %%
#активные компоненты, которые будут искаться

flags = [
    'Niacinamide 2–5 %',
    'Niacinamide > 5 %',
    'nicotinamide',
    'Vitamin C Ascorbic Acid ≤ 5 %',
    'Ascorbic Acid',
    'Vitamin C Ascorbic Acid > 5 % рН ≤ 4',
    'Vitamin C',
    'Ascorbyl Glucoside',
    'Magnesium Ascorbyl Phosphate',
    '3-O-Ethyl Ascorbic Acid',
    'Sodium Ascorbyl Phosphate',
    'Tetrahexyldecyl Ascorbate',
    'Blue Retinol Bakuchiol',
    'Retinol',
    'Retinol Acetate',
    'Retinol Palmitate',
    'Retinal',
    'Retinyl Propionate',
    'Retinol Retinoate',
    'Retinol encapsulated and liposomal form',
    'Azelaic Acid',
    'Amino Acids + Peptides',
    'EGF',
    'Matrixyl',
    'Leuphasyl',
    'Argireline',
    'SYN-AKE',
    'ВНА-acids',
    'Salicylic Acid 0.5–2 % pH = 3–4',
    'salicylic acid',
    'salicylic',
    'AНА-acids',
    'Lactic Acid',
    'Glycolic Acid',
    'Mandelic Acid 2–10 %* рН = 3–4',
    'cyclandelate',
    'РНА-acids',
    'Lactobionic Acid',
    'Gluconolactone 2–10 % pH = 3–4',
    'Gluconolactone',
    'Benzoyl Peroxide 2.5–5 %',
    'Benzoyl Peroxide'
]

# %%
import sqlite3
import difflib
import re

# Функция для токенизации текста по символу ';'
def preprocess_text_by_semicolon(text):
    if text is None:
        return []  # Если текст None, возвращаем пустой список
    tokens = text.split(';')
    tokens = [token.strip().lower() for token in tokens]  # Очищаем от лишних пробелов и делаем строчными
    return tokens

# Функция для нахождения схожих слов
def find_similar_words(word, word_list, n=3, cutoff=0.6):
    return difflib.get_close_matches(word, word_list, n=n, cutoff=cutoff)

# Функция для проверки наличия компонентов и проставления флагов
def check_flags(compozition_text, flags):
    tokens = preprocess_text_by_semicolon(compozition_text)

    flag_results = {}

    # Для каждого компонента из списка флагов ищем его в токенах состава
    for flag in flags:
        similar_tokens = find_similar_words(flag, tokens)
        if flag.lower() in similar_tokens:
            flag_results[flag] = 1  # Есть точное или похожее совпадение
        elif len(similar_tokens) > 0:
            flag_results[flag] = 0  # Есть схожие слова, но не точные
        else:
            flag_results[flag] = -1  # Нет совпадений

    return flag_results

# Соединение с базой данных
conn = sqlite3.connect('/content/composition_vectors.db')
cursor = conn.cursor()

cursor.execute('SELECT itemId, composition_tokenized FROM tokenized_table')
rows = cursor.fetchall()

def column_exists(cursor, column_name):
    cursor.execute(f"PRAGMA table_info(tokenized_table)")  # Получаем информацию о столбцах
    columns = cursor.fetchall()
    return any(col[1] == column_name for col in columns)  # Проверяем, есть ли колонка

# Проставляем флаги для каждого компонента
for row in rows:
    product_id = row[0]
    compozition_text = row[1]

    # Получаем флаги для каждого компонента
    flag_results = check_flags(compozition_text, flags)

    # Обновляем базу данных новыми колонками с флагами
    for flag, flag_value in flag_results.items():
        column_name = normalize_ingredient_name(flag) # Создаем имя колонки

        if not column_exists(cursor, column_name):
            cursor.execute(f"ALTER TABLE tokenized_table ADD COLUMN {column_name} INTEGER")

        cursor.execute(f"UPDATE tokenized_table SET {column_name} = ? WHERE itemId = ?", (flag_value, product_id))  # Обновляем флаг для конкретного продукта

# Сохраняем изменения
conn.commit()
conn.close()

# %%
# Список запрещенных компонентов
banned_ingredients = [
    "Benzene",
    "Formaldehyde",
    "Chloroform",
    "Methanol",
    "1,2-Dichloroethane",
    "Nitrosamines",
    "Acetaldehyde",
    "Bis(2-ethylhexyl) phthalate (DEHP)",
    "Dibutyl phthalate (DBP)",
    "Diisobutyl phthalate (DIBP)",
    "Toluene",
    "DDT (Dichlorodiphenyltrichloroethane)",
    "Hexachlorobenzene",
    "Lindane",
    "CI 12150",
    "CI 42555",
    "PABA (Para-aminobenzoic acid)",
    "4-Methylbenzylidene camphor (4-MBC)",
    "Hydroquinone",
    "Cresols",
    "Musk ketone",
    "Musk xylene"
]

# прогоним предыдущий кусок с этим списком, чтобы найти запрещенные компоненты

# %% [markdown]
# ## Автоматическое определение характеристик из описаний продуктов
#
# В этом шаге извлекаем только `itemId` и `description_tokenized` из общей базы данных, чтобы автоматически определить ключевые косметические свойства продуктов, не опираясь на состав. Цель — классифицировать продукты по назначению: например, увлажняющий, антивозрастной, от акне, для чувствительной кожи и т.д.
#
# - создан список характеристик и синонимичных ключевых слов.
# - для каждой характеристики флаг `1` (найдено) или `0` (не найдено).
# - результаты в новой SQLite-базе `description_vectors.db` с таблицей `description_flags`, где каждая строка соответствует продукту и включает бинарные признаки.

# %%
#выделяем itemId и description_tokens в отдельную бд
import sqlite3

source_conn = sqlite3.connect('/content/full_products_database.db')
source_cursor = source_conn.cursor()

target_conn = sqlite3.connect('/content/description_features.db')
target_cursor = target_conn.cursor()

target_cursor.execute('''
    CREATE TABLE IF NOT EXISTS description_flags (
        itemId INTEGER PRIMARY KEY,
        description_tokens TEXT
    )
''')

source_cursor.execute('SELECT itemId, description_tokens FROM merged_table')
rows = source_cursor.fetchall()

for row in rows:
    target_cursor.execute('INSERT OR REPLACE INTO description_flags (itemId, description_tokens) VALUES (?, ?)', row)

target_conn.commit()
source_conn.close()
target_conn.close()

# %%
# Характеристики и ключевые слова, которые будут искаться среди токенов описаний
features = {
    "увлажняющий": ["увлажн", "влаг", "гидра", "hydrat", "moistur", "сухост", "сушит", "дегидра"],
    "антивозрастной": ["антивозраст", "anti-age", "antiaging", "возрастн", "морщин", "wrinkle", "омолож", "эластичн", "подтянут", "лифтинг", "лифт", "тонус", "зрелая", "зрелую"],
    "выравнивает_тон": ["тон кож", "выравниван", "ровн", "оттенк", "pigment", "гиперпигмент"],
    "питательный": ["питани", "питает", "насыща", "насыщен", "наполн", "восстанов", "vitamin", "витамин", "mineral", "минерал"],
    "для_чувствительной": ["чувствительн", "сенситив", "sensitive", "успокаив", "раздражен", "деликатн", "покраснен", "краснот", "розацеа", "купероз", "реактивн"],
    "для_жирной": ["жирн", "блеск", "матир", "себум", "sebum", "жирность", "shine", "oil", "маслян", "пори", "поры"],
    "от_акне": ["акне", "acne", "воспален", "высыпан", "прыщ", "угр", "comedon", "пост-акне", "постакне"],
    "для_проблемной": ["проблемн", "недостатк", "imperfect", "problem", "несовершенств"],
    "для_сухой": ["сух", "шелуш", "сушит", "шелушен", "flak", "peel", "сухост", "обезвожен", "dehydrat"],
    "для_комбинированной": ["комбинир", "combination", "смешан", "t-zone", "т-зон"],
    "можно_поверх_макияжа": ["поверх", "макияж", "makeup", "over makeup", "фиксац", "fixing"],
    "от_черных_точек": ["черные точки", "комедон", "сальные пробки", "очищение пор", "закупорка пор", "blackhead", "comedone", "pore cleansing"],
    "сияние_кожи": ["сияние", "блеск", "свечение", "glow"],

    "регенерирующий": ["регенер", "regener", "восстан", "воссоздан", "обновлен", "renew", "заживлен", "heal"],
    "матирующий": ["матир", "matte", "антиблеск", "блеск", "shine", "контроль себум"],
    "от_отеков": ["отек", "отечност", "puff", "мешк", "припухлост", "разгон лимф"],
    "для_обезвоженной": ["обезвож", "dehydrat", "водн баланс", "нехватк вод", "сухост"],
    "для_нормальной": ["нормальн", "normal", "сбалансир", "balance"],
    "spf_защита": ["spf", "солнцезащит", "sun protect", "uv", "ультрафиолет", "загар", "tan"],
    "энзимный": ["энзим", "enzyme", "фермент", "биоактив"],
    "уменьшает_поры": ["пор", "поры", "pore", "сужает пор", "чистые пор", "расширен пор"],
    "веганский": ["веган", "vegan", "растительн", "plant", "не тестир", "cruelty free"],
    "гипоаллергенный": ["гипоаллерген", "hypoallergen", "безопасн", "без раздражен"],
    "некомедогенный": ["некомедоген", "non-comedogen", "не закупор", "без закупор", "не блокирует пор"],
    "с_маслами": ["масло", "oil", "арган", "argan", "жожоба", "jojoba", "ши", "shea", "кокос", "coconut", "миндал", "almond"],
    "с_экстрактами": ["экстракт", "extract", "ромашк", "chamomile"],
    "минеральный": ["минерал", "mineral", "минеральн"],
    "органический": ["органическ", "organic", "био", "bio", "эко", "eco", "natural", "натуральн"],
    "для_подростков": ["подростк", "teen", "юнош", "молод", "young"],
    "ночной_уход": ["ночн", "night", "ночь", "сон", "sleep", "вечерн"],
    "дневной_уход": ["дневн", "day", "день", "утрен", "morning"],
    "успокаивающий": ["успок", "sooth", "calm", "peace", "мягк", "soft"],
    "очищающий": ["очищен", "clean", "purif", "детокс", "detox", "чист", "pure"],
    "отшелушивающий": ["отшелуш", "exfol", "скраб", "scrub", "пилинг", "peel"],
    "противовоспалительный": ["противовоспал", "anti-inflamm", "воспал", "inflamm", "покраснен", "redness"],
    "ароматизированный": ["аромат", "fragran", "запах", "smell", "парфюм", "perfum"],
    "неароматизированный": ["без запах", "no fragran", "без аромат", "без парфюм"],
    "гидрофильный": ["гидрофильн", "hydrophil", "водн", "water", "масло раств", "oil soluble"],
    "нежирный": ["нежирн", "non-greasy", "легк", "light", "быстро впитыва"],
    "плотный": ["плотн", "тяжел", "heavy", "густ", "thick"],
    "легкий": ["легк", "light", "невесом", "weightless", "воздушн", "airy"]
}

# %%
import sqlite3
import difflib


# Подключение к базе
db_path = "/content/description_features.db"
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

# Модификаторы
NEGATIONS = {"не", "без", "нет"}
SUPPORTS = {"для", "против"}

# Добавляем колонку, если её нет
cursor.execute("PRAGMA table_info(description_flags);")
existing_columns = {col[1] for col in cursor.fetchall()}

for feature in features:
    if feature not in existing_columns:
        cursor.execute(f"ALTER TABLE description_flags ADD COLUMN {feature} INTEGER DEFAULT 0;")

# Обработка описания
def process_description(text, features):
    tokens = text.lower().split()
    result = {}

    for feature, keywords in features.items():
        found = False
        suppressed = False

        for i, token in enumerate(tokens):
            prev = tokens[i - 1] if i > 0 else ""

            matches = difflib.get_close_matches(token, keywords, n=1, cutoff=0.7)
            if matches:
                if prev in NEGATIONS:
                    suppressed = True
                    break
                found = True

        result[feature] = 1 if found and not suppressed else 0

    return result

# Получаем данные и обновляем
cursor.execute("SELECT itemId, description_tokens FROM description_flags;")
rows = cursor.fetchall()

for item_id, text in rows:
    flags = process_description(text, features)

    for feature, value in flags.items():
        cursor.execute(
            f"UPDATE description_flags SET {feature} = ? WHERE itemId = ?",
            (value, item_id)
        )

conn.commit()
conn.close()

# %% [markdown]
# ## Формирование правил (CLIPS)
#
# В данном шаге генерируются правила для системы CLIPS на основе данных из базы данных, которая содержит информацию о сочетаниях компонентов косметических средств (из пункта 3). Используем SQL запросы для извлечения информации и формируем соответствующие правила.
#
# - читаем таблицу с данными о сочетаниях компонентов (first_element, second_element), а также результатах их взаимодействия (result) и дополнительными комментариями (comment).
#
# - на основе каждого сочетания компонентов (например, первого и второго элемента) формируется правило для системы CLIPS. В каждом правиле проверяется наличие двух компонентов в списке элементов. Если они присутствуют, то активируется факт с результатом (например, результат взаимодействия этих компонентов).

# %%
import sqlite3
from IPython.display import display, Markdown

# Подключение к SQLite
conn = sqlite3.connect("components-combo-3.db")
cursor = conn.cursor()

# Получаем данные из таблицы
cursor.execute("SELECT first_element, second_element, result, comment FROM components")
rows = cursor.fetchall()
conn.close()

# Генерация правил CLIPS с использованием (or)
clips_rules = []
for i, (first, second, result, comment) in enumerate(rows, 1):
    # Формируем информационное сообщение, если comment не пустой
    info_fact = ""
    if result in ["-1", "0"] or comment:
        info_message = f"Сочетание {first} и {second}: "
        if result == "-1":
            info_message += "Отрицательное взаимодействие"
        elif result == "0":
            info_message += "Есть ограничения по взаимодействию"
        elif result == "1":
            info_message += "Можно сочетать"
        if comment:
            info_message += f", {comment}"
        info_fact = f'(assert (info "{info_message}"))'

    rule = f"""
(defrule правило_{i}
    (or
        (and (first_element "{first}") (second_element "{second}"))
        (and (first_element "{second}") (second_element "{first}"))
    )
    =>
    (assert (result "{result}"))
    {info_fact}
)"""
    clips_rules.append(rule)

# Объединяем все правила
clips_code = "\n".join(clips_rules)

# Красивый вывод с подсветкой синтаксиса
display(Markdown(f"```clips\n{clips_code}\n```"))

# Сохранение в файл
with open("generated_rules_new.clp", "w") as f:
    f.write(clips_code)

print(f"Сгенерировано {len(rows)} правил. Файл: 'generated_rules_new.clp'")

# %% [markdown]
# Добавим правила, которые отрабатывают, если был найден компонент из списка запрещенных

# %%
# Список запрещенных компонентов
banned_ingredients = [
    "Benzene",
    "Formaldehyde",
    "Chloroform",
    "Methanol",
    "1,2-Dichloroethane",
    "Nitrosamines",
    "Acetaldehyde",
    "Bis(2-ethylhexyl) phthalate (DEHP)",
    "Dibutyl phthalate (DBP)",
    "Diisobutyl phthalate (DIBP)",
    "Toluene",
    "DDT (Dichlorodiphenyltrichloroethane)",
    "Hexachlorobenzene",
    "Lindane",
    "CI 12150",
    "CI 42555",
    "PABA (Para-aminobenzoic acid)",
    "4-Methylbenzylidene camphor (4-MBC)",
    "Hydroquinone",
    "Cresols",
    "Musk ketone",
    "Musk xylene"
]

clips_rules = []

for i, ingredient in enumerate(banned_ingredients, 1):
    rule = f"""
(defrule banned_ingredient_{i}
    (element "{ingredient}")
    =>
    (assert (result "-1"))
    (assert (info "Внимание! Обнаружен запрещённый компонент: {ingredient}"))
)
"""
    clips_rules.append(rule)

clips_code = "\n".join(clips_rules)

with open("banned_ingredients_rules.clp", "w") as f:
    f.write(clips_code)

print(f"Сгенерировано {len(banned_ingredients)} правил. Файл: 'banned_ingredients_rules.clp'")
# Out:
# Сгенерировано 22 правил. Файл: 'banned_ingredients_rules.clp'

# %%
# после всех правил, которые выдают промежуточные результаты,
# добавляем правила, которые обрабатывают промежуточные и формируют финальный результат и степень (насколько хорошо или плохо)

# ниже три правила, которые просто добавляются в .clp
# ;; Глобальные переменные для подсчёта результатов
# (defglobal ?*count_neg1* = 0)
# (defglobal ?*count_0* = 0)
# (defglobal ?*count_1* = 0)

# ;; Правило для создания финального результата "-1" и подсчёта
# (defrule set_final_minus_1
#     (result "-1")
#     =>
#     (bind ?*count_neg1* (+ ?*count_neg1* 1))  ;; Увеличиваем счётчик -1
#     (assert (final_result "-1"))  ;; Создаём факт "final_result"

#     ;; Создание факта "степень" на основе подсчёта -1 (счётчик)
#     (assert (degree ?*count_neg1*))  ;; Факт "degree" с числовым значением счётчика -1

#     (halt)  ;; Завершаем выполнение
# )

# ;; Правило для создания финального результата "0" и подсчёта
# (defrule set_final_0
#     (not (result "-1"))
#     (result "0")
#     =>
#     (bind ?*count_0* (+ ?*count_0* 1))  ;; Увеличиваем счётчик 0
#     (assert (final_result "0"))  ;; Создаём факт "final_result"

#     ;; Создание факта "степень" на основе подсчёта 0 (счётчик)
#     (assert (degree ?*count_0*))  ;; Факт "degree" с числовым значением счётчика 0

#     (halt)  ;; Завершаем выполнение
# )

# ;; Правило для создания финального результата "1" и подсчёта
# (defrule set_final_1
#     (not (result "-1"))
#     (not (result "0"))
#     (result "1")
#     =>
#     (bind ?*count_1* (+ ?*count_1* 1))  ;; Увеличиваем счётчик 1
#     (assert (final_result "1"))  ;; Создаём факт "final_result"

#     ;; Создание факта "степень" на основе подсчёта 1 (счётчик)
#     (assert (degree ?*count_1*))  ;; Факт "degree" с числовым значением счётчика 1

#     (halt)  ;; Завершаем выполнение
# )

# %%
# Характеристики из описаний средств, относительно которых будут строится правила
features = [
    "увлажняющий",
    "антивозрастной",
    "выравнивает_тон",
    "питательный",
    "для_чувствительной",
    "для_жирной",
    "от_акне",
    "для_проблемной",
    "для_сухой",
    "для_комбинированной",
    "можно_поверх_макияжа",
    "от_черных_точек",
    "сияние_кожи",

    "регенерирующий",
    "матирующий",
    "от_отеков",
    "для_обезвоженной",
    "для_нормальной",
    "spf_защита",
    "пилинг",
    "энзимный",
    "уменьшает_поры",
    "веганский",
    "гипоаллергенный",
    "некомедогенный",
    "с_маслами",
    "с_экстрактами",
    "минеральный",
    "органический",
    "для_подростков",
    "ночной_уход",
    "дневной_уход",
    "успокаивающий",
    "очищающий",
    "отшелушивающий",
    "противовоспалительный",
    "ароматизированный",
    "неароматизированный",
    "гидрофильный",
    "нежирный",
    "плотный",
    "легкий"
]

# %%
# характеристики пользователя, по которым строятся правила (слева типы фактов, справа чему они могут быть равны)
user_characteristics = {
    "skin_type": ["Сухая", "Жирная", "Комбинированная"],
    "sensitive_skin": ["Да"],
    "tendencies": ["Воспаления", "Акне", "Расширенные_поры", "Шелушения", "Пигментация", "Возрастная_кожа"],
    "age" :["Подростковая", "Молодая", "Зрелая"],
    "had_procedure":["Да", "Нет"],
    "procedure_types":["Инъекции", "Пилинг", "Механическая чистка"],
    "has_allergy":["Да"],
    #"Аллергии_на_компоненты", компоненты будут искаться в составе отдельной функцией, а не правилами

    "weather":["Солнечная", "Тёплая", "Пасмурная", "Холодная"],
    "makeup":["Да", "Нет"]
}

# %%
import sqlite3

conn = sqlite3.connect('product_user_characteristics.db')
cursor = conn.cursor()

cursor.execute('''
CREATE TABLE IF NOT EXISTS characteristics_rules (
    product_feature TEXT,
    user_fact TEXT,
    user_feature TEXT,
    info TEXT
)
''')

for feature in features:
    for fact, user_features in user_characteristics.items():
        for user_feature in user_features:
            cursor.execute('''
            INSERT INTO characteristics_rules (product_feature, user_fact, user_feature, info)
            VALUES (?, ?, ?, ?)
            ''', (feature, fact, user_feature, ''))

conn.commit()
conn.close()

print("Таблица успешно создана и заполнена.")
# Out:
# Таблица успешно создана и заполнена.

# %% [markdown]
# Заполняем столбец info рекомендациями (если рекомендаций по паре нет, то строку удаляем), добавляем столбец result - окрас рекомендации (1 - положительная, 0 - внимание, -1 - отрицательная).
# Добавим автоматическую генераци правил по этой таблице

# %%
import sqlite3
from IPython.display import display, Markdown

conn = sqlite3.connect("product_user_characteristics.db")
cursor = conn.cursor()

cursor.execute("SELECT product_feature, user_fact, user_feature, result, info FROM characteristics_rules")
rows = cursor.fetchall()
conn.close()

clips_rules = []
for i, (product_feat, user_fact, user_feat, result, info) in enumerate(rows, 1):
    info_fact = f'(assert (info "{result}, {info}"))' if info else ""

    rule = f"""
(defrule rule_{i}
    (product_feature "{product_feat}")
    (user_fact {user_fact} "{user_feat}")
    =>
    (assert (result "{result}"))
    {info_fact}
)"""
    clips_rules.append(rule.strip())

clips_code = "\n\n".join(clips_rules)

display(Markdown(f"```clips\n{clips_code}\n```"))

with open("user_product_rules.clp", "w") as f:
    f.write(clips_code)

print(f"Сгенерировано {len(rows)} правил. Файл: 'user_product_rules.clp'")

# %%
# #также добавим пару правил, которые не генерируются автоматически по таблице:
# (defrule new_to_retinol
#     (element "Retinol")
#     =>
#     (assert (info "Если раньше не пользовались ретинолом, начинайте с малого количества и постепенно увеличивайте дозу, чтобы избежать раздражения."))
# )
# (defrule sun-warning
#   (weather "Солнечная")
#   (or
#     (element "Retinol")
#     (element "Blue Retinol Bakuchiol")
#     (element "Retinol Acetate")
#     (element "Retinol Palmitate")
#     (element "Retinal")
#     (element "Retinyl Propionate")
#     (element "Retinol Retinoate")
#     (element "Retinol encapsulated and liposomal form")
#     (element "AHA-acids")
#     (element "Lactic Acid")
#     (element "Glycolic Acid")
#     (element "Mandelic Acid 2–10 %* рН = 3–4")
#     (element "BHA-acids")
#     (element "Salicylic Acid 0.5–2 % pH = 3–4")
#     (element "salicylic acid")
#     (element "salicylic")
#     (element "PHA-acids")
#     (element "Lactobionic Acid")
#     (element "Gluconolactone 2–10 % pH = 3–4")
#     (element "Gluconolactone")
#     (element "Azelaic Acid")
#     (element "Benzoyl Peroxide 2.5–5 %")
#     (element "Benzoyl Peroxide")
#   )
#   =>
#   (assert (info "Поскольку погода солнечная и используются фотосенсибилизирующие компоненты, обязательно применяйте SPF 50+ для защиты кожи."))
# )
